# %%
import pandas as pd
from freesurfer_stats import CorticalParcellationStats
import glob
import re
import itertools
import numpy as np
import pyls
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
import pickle
from sklearn import preprocessing
from scipy.stats import zscore
from nilearn import input_data
from nilearn import plotting
# Out:
# /opt/miniconda3/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
sns.set_context("notebook", font_scale=1.7)
sns.set_style("whitegrid")

# %% [markdown]
# ## PLS ANALYSIS

# %%
all_volumes_file = 'data/all_volumes.csv'
all_volumes = pd.read_csv(all_volumes_file)
all_volumes.drop(columns=all_volumes.columns[0], axis=1, inplace=True)
#all_volumes.columns.to_list()

# %%
# Selección de estructuras, no se inlcluye el 5to ventrículo
columns = list(range(0,15)) + list(range(21,54)) + list(range(61,467))
#columns = list(range(0,4)) + list(range(21,54)) + list(range(61,467))
selected_values = all_volumes.iloc[:,columns]
#list(selected_values.columns)
#selected_values

# %% [markdown]
# ## NORMALIZATION BY ETIV

# %%
selected_values.iloc[:,3:] = selected_values.iloc[:,3:].div(selected_values["Estimated Total Intracranial Volume"], axis=0)
#selected_values
# Out:
# /var/folders/wp/_tyy4sn10dn9tbjvll8p76m80000gr/T/ipykernel_30892/2149581007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_values.iloc[:,3:] = selected_values.iloc[:,3:].div(selected_values["Estimated Total Intracranial Volume"], axis=0)

# %%
all_data = selected_values
#all_data[all_data['subject']=='TABP079']

# %%
# Remover columna de ETIV
all_data = all_data.drop(['Estimated Total Intracranial Volume'],axis=1)
#all_data

# %% [markdown]
# ## Clinical data

# %%
clinical_file = 'clinical_data.xlsx'
clinical_data = pd.read_excel(clinical_file,'master')
#clinical_data

# %%
clinical_data = clinical_data.iloc[:, [9,0,2,3,4,5,6,7,8,15]]
clinical_data.rename(columns = {'id_RM':'subject'}, inplace = True)
#clinical_data

# %%
clinical_data
# Out:
#      subject Group  time  treatment  edad  gen   esc   dx  psc  Gravedad
# 0    TABP001   TAB     1        2.0  46.0  0.0  17.0  1.0  0.0  0.714286
# 1    TABP001   TAB     2        2.0  48.0  NaN  17.0  1.0  0.0  0.000000
# 2    TABP001   TAB     3        2.0  52.0  NaN  17.0  1.0  0.0  0.461538
# 3    TABP003   TAB     1        1.0  35.0  0.0   6.0  1.0  0.0  0.400000
# 4    TABP003   TAB     2        1.0  37.0  NaN   6.0  1.0  0.0  0.000000
# ..       ...   ...   ...        ...   ...  ...   ...  ...  ...       ...
# 491  CTRL024   CTR     3        0.0  37.0  1.0  13.0  0.0  0.0  0.000000
# 492  CTRL025   CTR     3        0.0  49.0  0.0  11.0  0.0  0.0  0.000000
# 493  CTRL026   CTR     3        0.0  56.0  0.0   5.0  0.0  0.0  0.000000
# 494  CTRL027   CTR     3        0.0  41.0  1.0  12.0  0.0  0.0  0.000000
# 495  CTRL028   CTR     3        0.0  28.0  1.0  16.0  0.0  0.0  0.000000
#
# [496 rows x 10 columns]

# %% [markdown]
# ## Edit file

# %%
pd.set_option('display.max_rows', None)

#add same treatment in all times
l=['Group','time','edad','gen','esc','dx','psc', 'Gravedad'] # column different from each row
clinical_data_f = pd.concat([clinical_data.drop(l,1).groupby('subject').transform('first'),clinical_data[l],clinical_data[['subject']]],axis=1).reindex(columns=clinical_data.columns)

clinical_data_f['project'] = 'prisma'+ clinical_data_f.time.astype(str)

clinical_data_f.loc[clinical_data_f.Group == 'CTR', 'project'] = "controles"
# Agregar condición
#clinical_data_f['c_group'] = clinical_data_f['Group'] + '-' + clinical_data_f['project'] +'-' +'treatment' + clinical_data_f['treatment'].astype(str)
clinical_data_f['c_group'] = clinical_data_f['Group'] + '-' + clinical_data_f['project']
# Out:
# /var/folders/wp/_tyy4sn10dn9tbjvll8p76m80000gr/T/ipykernel_30892/3466945000.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   clinical_data_f = pd.concat([clinical_data.drop(l,1).groupby('subject').transform('first'),clinical_data[l],clinical_data[['subject']]],axis=1).reindex(columns=clinical_data.columns)

# %%
clinical_data_f
# Out:
#      subject Group  time  treatment  edad  gen   esc   dx  psc  Gravedad  \
# 0    TABP001   TAB     1        2.0  46.0  0.0  17.0  1.0  0.0  0.714286
# 1    TABP001   TAB     2        2.0  48.0  NaN  17.0  1.0  0.0  0.000000
# 2    TABP001   TAB     3        2.0  52.0  NaN  17.0  1.0  0.0  0.461538
# 3    TABP003   TAB     1        1.0  35.0  0.0   6.0  1.0  0.0  0.400000
# 4    TABP003   TAB     2        1.0  37.0  NaN   6.0  1.0  0.0  0.000000
# 5    TABP003   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 6    TABP004   TAB     1        2.0  55.0  0.0  15.0  1.0  1.0  0.142857
# 7    TABP004   TAB     2        2.0  56.0  NaN   NaN  1.0  0.0  0.000000
# 8    TABP004   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 9    TABP012   TAB     1        2.0  50.0  0.0   6.0  1.0  1.0  0.200000
# 10   TABP012   TAB     2        2.0  52.0  NaN   6.0  1.0  0.0  0.000000
# 11   TABP012   TAB     3        2.0  56.0  NaN   6.0  1.0  0.0  0.064516
# 12   TABP060   TAB     1        1.0  57.0  1.0  11.0  1.0  0.0  1.379310
# 13   TABP060   TAB     2        1.0  58.0  NaN   NaN  1.0  0.0  0.000000
# 14   TABP060   TAB     3        1.0  63.0  NaN  11.0  1.0  0.0  0.000000
# 15   TABP057   TAB     1        2.0  28.0  1.0  13.0  1.0  1.0       NaN
# 16   TABP057   TAB     2        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 17   TABP057   TAB     3        2.0  34.0  NaN  13.0  1.0  0.0  0.571429
# 18   TABP013   TAB     1        2.0  57.0  0.0  11.0  1.0  1.0  0.769231
# 19   TABP013   TAB     2        2.0  58.0  NaN   NaN  1.0  0.0  0.000000
# 20   TABP013   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 21   TABP009   TAB     1        2.0  52.0  0.0   8.0  1.0  0.0  0.172414
# 22   TABP009   TAB     2        2.0  53.0  NaN   NaN  1.0  0.0  0.000000
# 23   TABP009   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 24   TABP010   TAB     1        2.0  52.0  0.0   5.0  1.0  0.0  1.000000
# 25   TABP010   TAB     2        2.0  53.0  NaN   NaN  1.0  0.0  0.200000
# 26   TABP010   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 27   TABP017   TAB     1        1.0  37.0  0.0  15.0  1.0  1.0  0.391304
# 28   TABP017   TAB     2        1.0  39.0  NaN   NaN  1.0  0.0  0.040000
# 29   TABP017   TAB     3        1.0  44.0  NaN  15.0  1.0  1.0  0.133333
# 30   TABP021   TAB     1        2.0  43.0  0.0  12.0  1.0  1.0  0.714286
# 31   TABP021   TAB     2        2.0  45.0  NaN   NaN  1.0  0.0  0.000000
# 32   TABP021   TAB     3        2.0  49.0  NaN  12.0  1.0  0.0  0.307692
# 33   TABP030   TAB     1        2.0  55.0  1.0   2.0  1.0  1.0  0.236842
# 34   TABP030   TAB     2        2.0  57.0  NaN   NaN  1.0  1.0  0.100000
# 35   TABP030   TAB     3        2.0  61.0  NaN   2.0  1.0  0.0  0.000000
# 36   TABP074   TAB     1        2.0  53.0  1.0  17.0  1.0  0.0  0.666667
# 37   TABP074   TAB     2        2.0  54.0  NaN   NaN  1.0  0.0  0.000000
# 38   TABP074   TAB     3        2.0  58.0  NaN  17.0  1.0  0.0  0.000000
# 39   TABP023   TAB     1        2.0  37.0  1.0  12.0  1.0  1.0  0.181818
# 40   TABP023   TAB     2        2.0  39.0  NaN   NaN  NaN  0.0  0.000000
# 41   TABP023   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 42   TABP073   TAB     1        2.0  55.0  0.0   8.0  1.0  1.0  0.388889
# 43   TABP073   TAB     2        2.0  56.0  NaN   NaN  NaN  0.0  0.000000
# 44   TABP073   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 45   TABP015   TAB     1        1.0  33.0  0.0  11.0  1.0  0.0  1.200000
# 46   TABP015   TAB     2        1.0  34.0  NaN   NaN  1.0  0.0  0.181818
# 47   TABP015   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 48   TABP029   TAB     1        2.0  46.0  0.0   9.0  1.0  1.0  0.791667
# 49   TABP029   TAB     2        2.0  47.0  NaN   NaN  1.0  0.0  0.040000
# 50   TABP029   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 51   TABP066   TAB     1        2.0  50.0  0.0  14.0  1.0  1.0  0.228571
# 52   TABP066   TAB     2        2.0  51.0  NaN   NaN  1.0  1.0  0.083333
# 53   TABP066   TAB     3        2.0  56.0  NaN  16.0  1.0  0.0  0.121951
# 54   TABP103   TAB     1        1.0  46.0  1.0  14.0  1.0  1.0  0.137931
# 55   TABP103   TAB     2        1.0  48.0  NaN   NaN  1.0  0.0  0.000000
# 56   TABP103   TAB     3        1.0  52.0  NaN  14.0  1.0  1.0  0.000000
# 57   TABP100   TAB     1        1.0  49.0  1.0  11.0  1.0  1.0  0.703704
# 58   TABP100   TAB     2        1.0  50.0  NaN   NaN  1.0  0.0  0.000000
# 59   TABP100   TAB     3        1.0  55.0  NaN  13.0  1.0  0.0  0.060606
# 60   TABP069   TAB     1        2.0  40.0  0.0  12.0  1.0  1.0  0.533333
# 61   TABP069   TAB     2        2.0  41.0  NaN   NaN  1.0  0.0  0.062500
# 62   TABP069   TAB     3        2.0  46.0  NaN  13.0  1.0  0.0  0.000000
# 63   TABP022   TAB     1        1.0  52.0  1.0   6.0  1.0  0.0  0.321429
# 64   TABP022   TAB     2        1.0  53.0  NaN   NaN  1.0  0.0  0.068966
# 65   TABP022   TAB     3        1.0  59.0  NaN   6.0  1.0  1.0  0.200000
# 66   TABP005   TAB     1        1.0  43.0  0.0  12.0  1.0  1.0  0.333333
# 67   TABP005   TAB     2        1.0  45.0  NaN   NaN  1.0  0.0  0.000000
# 68   TABP005   TAB     3        1.0  51.0  NaN  12.0  1.0  0.0  0.000000
# 69   TABP070   TAB     1        2.0  51.0  1.0  10.0  1.0  1.0  0.153846
# 70   TABP070   TAB     2        2.0  52.0  NaN   NaN  1.0  0.0  0.000000
# 71   TABP070   TAB     3        2.0  58.0  NaN  10.0  1.0  1.0  0.100000
# 72   TABP008   TAB     1        2.0  42.0  0.0  10.0  1.0  0.0  1.571429
# 73   TABP008   TAB     2        2.0  43.0  NaN   NaN  1.0  0.0  0.090909
# 74   TABP008   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 75   TABP007   TAB     1        1.0  56.0  1.0  11.0  1.0  1.0  0.135135
# 76   TABP007   TAB     2        1.0  57.0  NaN   NaN  1.0  0.0  0.026316
# 77   TABP007   TAB     3        1.0  62.0  NaN  11.0  1.0  0.0  0.023256
# 78   TABP011   TAB     1        2.0  58.0  0.0  16.0  1.0  0.0  1.200000
# 79   TABP011   TAB     2        2.0  59.0  NaN   NaN  1.0  0.0  0.000000
# 80   TABP011   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 81   TABP067   TAB     1        1.0  44.0  0.0  12.0  1.0  1.0  1.173913
# 82   TABP067   TAB     2        1.0  45.0  NaN   NaN  1.0  0.0  0.041667
# 83   TABP067   TAB     3        1.0  50.0  NaN  12.0  1.0  NaN  0.137931
# 84   TABP089   TAB     1        1.0  54.0  0.0   9.0  1.0  1.0  0.625000
# 85   TABP089   TAB     2        1.0  55.0  NaN   NaN  1.0  1.0  0.444444
# 86   TABP089   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 87   TABP014   TAB     1        2.0  58.0  0.0   5.0  1.0  0.0  0.176471
# 88   TABP014   TAB     2        2.0  59.0  NaN   NaN  1.0  0.0  0.000000
# 89   TABP014   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 90   TABP016   TAB     1        2.0  52.0  0.0  13.0  1.0  1.0  0.285714
# 91   TABP016   TAB     2        2.0  53.0  NaN   NaN  1.0  1.0  0.055556
# 92   TABP016   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 93   TABP019   TAB     1        1.0  50.0  1.0  15.0  1.0  0.0  0.837838
# 94   TABP019   TAB     2        1.0  51.0  NaN   NaN  1.0  0.0  0.000000
# 95   TABP019   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 96   TABP018   TAB     1        1.0  52.0  1.0  15.0  1.0  0.0  0.031250
# 97   TABP018   TAB     2        1.0  54.0  NaN   NaN  1.0  0.0  0.029412
# 98   TABP018   TAB     3        1.0  59.0  NaN  15.0  1.0  0.0  0.025641
# 99   TABP020   TAB     1        2.0  53.0  0.0   7.0  1.0  1.0  1.550000
# 100  TABP020   TAB     2        2.0  54.0  NaN   NaN  1.0  1.0  0.095238
# 101  TABP020   TAB     3        2.0  60.0  NaN   7.0  1.0  0.0  0.074074
# 102  TABP024   TAB     1        2.0  44.0  0.0  15.0  1.0  1.0  0.814815
# 103  TABP024   TAB     2        2.0  45.0  NaN   NaN  NaN  0.0  0.000000
# 104  TABP024   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 105  TABP025   TAB     1        2.0  27.0  0.0  12.0  1.0  0.0  0.500000
# 106  TABP025   TAB     2        2.0  28.0  NaN   NaN  1.0  0.0  0.000000
# 107  TABP025   TAB     3        2.0  33.0  NaN  12.0  1.0  1.0  1.100000
# 108  TABP101   TAB     1        2.0  31.0  0.0  12.0  1.0  0.0  2.000000
# 109  TABP101   TAB     2        2.0  32.0  NaN   NaN  1.0  1.0  0.200000
# 110  TABP101   TAB     3        2.0  38.0  NaN  12.0  1.0  0.0  0.500000
# 111  TABP026   TAB     1        1.0  57.0  0.0   6.0  1.0  1.0  0.823529
# 112  TABP026   TAB     2        1.0  59.0  NaN   NaN  1.0  0.0  0.000000
# 113  TABP026   TAB     3        1.0  64.0  NaN   7.0  1.0  0.0  0.375000
# 114  TABP027   TAB     1        2.0  42.0  1.0   6.0  1.0  0.0  4.333333
# 115  TABP027   TAB     2        2.0  42.0  NaN   NaN  1.0  NaN  0.166667
# 116  TABP027   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 117  TABP032   TAB     1        2.0  29.0  0.0  11.0  1.0  0.0  4.500000
# 118  TABP032   TAB     2        2.0  30.0  NaN   NaN  1.0  1.0  1.333333
# 119  TABP032   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 120  TABP031   TAB     1        2.0  53.0  1.0   8.0  2.0  0.0       NaN
# 121  TABP031   TAB     2        2.0  54.0  NaN   NaN  1.0  0.0  0.000000
# 122  TABP031   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 123  TABP055   TAB     1        1.0  24.0  1.0  14.0  1.0  0.0  0.909091
# 124  TABP055   TAB     2        1.0  25.0  NaN   NaN  1.0  0.0  0.083333
# 125  TABP055   TAB     3        1.0  30.0  NaN  14.0  1.0  0.0  0.000000
# 126  TABP106   TAB     1        1.0  59.0  0.0  12.0  1.0  0.0  0.277778
# 127  TABP106   TAB     2        1.0  61.0  NaN   NaN  1.0  0.0  0.000000
# 128  TABP106   TAB     3        1.0  66.0  NaN  12.0  1.0  0.0  0.000000
# 129  TABP062   TAB     1        1.0  53.0  0.0  11.0  1.0  0.0  0.500000
# 130  TABP062   TAB     2        1.0  54.0  NaN   NaN  1.0  0.0  0.111111
# 131  TABP062   TAB     3        1.0  59.0  NaN  11.0  1.0  0.0  0.000000
# 132  TABP033   TAB     1        2.0  43.0  0.0  11.0  1.0  0.0  0.142857
# 133  TABP033   TAB     2        2.0  44.0  NaN   NaN  1.0  0.0  0.000000
# 134  TABP033   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 135  TABP034   TAB     1        2.0  32.0  1.0  17.0  1.0  0.0  0.600000
# 136  TABP034   TAB     2        2.0  33.0  NaN   NaN  1.0  0.0  0.000000
# 137  TABP034   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 138  TABP035   TAB     1        1.0  29.0  1.0  14.0  1.0  1.0  0.600000
# 139  TABP035   TAB     2        1.0  30.0  NaN   NaN  1.0  0.0  0.000000
# 140  TABP035   TAB     3        1.0  35.0  NaN  15.0  1.0  0.0  0.000000
# 141  TABP036   TAB     1        1.0  35.0  0.0   2.0  1.0  1.0  1.714286
# 142  TABP036   TAB     2        1.0  36.0  NaN   NaN  1.0  1.0  0.066667
# 143  TABP036   TAB     3        1.0  42.0  NaN   2.0  1.0  1.0  0.142857
# 144  TABP037   TAB     1        1.0  26.0  1.0  13.0  1.0  1.0  0.428571
# 145  TABP037   TAB     2        1.0  27.0  NaN   NaN  1.0  0.0  0.000000
# 146  TABP037   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 147  TABP041   TAB     1        1.0  22.0  0.0  13.0  1.0  0.0  3.875000
# 148  TABP041   TAB     2        1.0  23.0  NaN   NaN  1.0  0.0  0.111111
# 149  TABP041   TAB     3        1.0  28.0  NaN  16.0  1.0  1.0  0.285714
# 150  TABP039   TAB     1        1.0  24.0  0.0  16.0  2.0  0.0  1.000000
# 151  TABP039   TAB     2        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 152  TABP039   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 153  TABP040   TAB     1        2.0  46.0  1.0  11.0  1.0  0.0  3.357143
# 154  TABP040   TAB     2        2.0  47.0  NaN   NaN  1.0  1.0  0.068966
# 155  TABP040   TAB     3        2.0  53.0  NaN  11.0  1.0  0.0  0.200000
# 156  TABP042   TAB     1        1.0  46.0  1.0  13.0  1.0  0.0  1.120000
# 157  TABP042   TAB     2        1.0  47.0  NaN   NaN  1.0  0.0  0.000000
# 158  TABP042   TAB     3        1.0  52.0  NaN  13.0  1.0  0.0  0.258065
# 159  TABP043   TAB     1        2.0  39.0  0.0  11.0  1.0  0.0  1.478261
# 160  TABP043   TAB     2        2.0  40.0  NaN   NaN  1.0  1.0  0.083333
# 161  TABP043   TAB     3        2.0  45.0  NaN  13.0  1.0  1.0  0.620690
# 162  TABP086   TAB     1        1.0  50.0  0.0  11.0  1.0  1.0  0.206897
# 163  TABP086   TAB     2        1.0  51.0  NaN   NaN  1.0  0.0  0.000000
# 164  TABP086   TAB     3        1.0  56.0  NaN  11.0  1.0  0.0  0.000000
# 165  TABP044   TAB     1        1.0  53.0  0.0  14.0  1.0  1.0  0.100000
# 166  TABP044   TAB     2        1.0  55.0  NaN   NaN  1.0  0.0  0.000000
# 167  TABP044   TAB     3        1.0  60.0  NaN  14.0  1.0  0.0  0.000000
# 168  TABP097   TAB     1        2.0  57.0  1.0   2.0  1.0  1.0  0.725000
# 169  TABP097   TAB     2        2.0  58.0  NaN   NaN  1.0  0.0  0.000000
# 170  TABP097   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 171  TABP045   TAB     1        1.0  45.0  0.0   6.0  1.0  1.0  0.323529
# 172  TABP045   TAB     2        1.0  46.0  NaN   NaN  1.0  0.0  0.000000
# 173  TABP045   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 174  TABP052   TAB     1        2.0  42.0  1.0   4.0  1.0  1.0  0.160000
# 175  TABP052   TAB     2        2.0  43.0  NaN   NaN  1.0  0.0  0.000000
# 176  TABP052   TAB     3        2.0  48.0  NaN   4.0  1.0  0.0  0.000000
# 177  TABP046   TAB     1        2.0  47.0  0.0  11.0  1.0  0.0  0.235294
# 178  TABP046   TAB     2        2.0  49.0  NaN   NaN  1.0  0.0  0.000000
# 179  TABP046   TAB     3        2.0  55.0  NaN  11.0  1.0  0.0  0.000000
# 180  TABP048   TAB     1        2.0  22.0  0.0  12.0  1.0  0.0  1.285714
# 181  TABP048   TAB     2        2.0  23.0  NaN   NaN  1.0  0.0  0.000000
# 182  TABP048   TAB     3        2.0  29.0  NaN  13.0  1.0  0.0  0.000000
# 183  TABP047   TAB     1        1.0  30.0  0.0  15.0  1.0  0.0  0.769231
# 184  TABP047   TAB     2        1.0  31.0  NaN   NaN  1.0  0.0  0.000000
# 185  TABP047   TAB     3        1.0  37.0  NaN  16.0  1.0  0.0  0.100000
# 186  TABP053   TAB     1        2.0  24.0  0.0  13.0  2.0  0.0  2.444444
# 187  TABP053   TAB     2        2.0  25.0  NaN   NaN  2.0  0.0  0.100000
# 188  TABP053   TAB     3        2.0  30.0  NaN  13.0  2.0  1.0  0.866667
# 189  TABP049   TAB     1        1.0  49.0  0.0  16.0  1.0  1.0  0.233333
# 190  TABP049   TAB     2        1.0  50.0  NaN   NaN  1.0  0.0  0.032258
# 191  TABP049   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 192  TABP051   TAB     1        2.0  56.0  0.0   5.0  2.0  0.0  0.714286
# 193  TABP051   TAB     2        2.0  57.0  NaN   NaN  2.0  0.0  0.000000
# 194  TABP051   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 195  TABP054   TAB     1        1.0  33.0  0.0  16.0  1.0  1.0  1.388889
# 196  TABP054   TAB     2        1.0  34.0  NaN   NaN  1.0  0.0  0.052632
# 197  TABP054   TAB     3        1.0  39.0  NaN  16.0  1.0  1.0  0.166667
# 198  TABP056   TAB     1        1.0  49.0  0.0  21.0  2.0  0.0  0.206897
# 199  TABP056   TAB     2        1.0  49.0  NaN   NaN  2.0  0.0  0.000000
# 200  TABP056   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 201  TABP058   TAB     1        1.0  56.0  0.0   8.0  1.0  1.0  0.642857
# 202  TABP058   TAB     2        1.0  57.0  NaN   NaN  1.0  0.0  0.046512
# 203  TABP058   TAB     3        1.0  62.0  NaN  10.0  1.0  0.0  0.083333
# 204  TABP059   TAB     1        1.0  32.0  1.0  16.0  1.0  0.0  1.857143
# 205  TABP059   TAB     2        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 206  TABP059   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 207  TABP061   TAB     1        1.0  24.0  0.0  12.0  1.0  0.0  0.571429
# 208  TABP061   TAB     2        1.0  25.0  NaN   NaN  1.0  0.0  0.000000
# 209  TABP061   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 210  TABP063   TAB     1        2.0  27.0  1.0  14.0  1.0  0.0  2.000000
# 211  TABP063   TAB     2        2.0  28.0  NaN   NaN  1.0  0.0  0.000000
# 212  TABP063   TAB     3        2.0  33.0  NaN  15.0  1.0  0.0  0.500000
# 213  TABP065   TAB     1        1.0  34.0  1.0  13.0  1.0  1.0  2.125000
# 214  TABP065   TAB     2        1.0  35.0  NaN   NaN  1.0  1.0  0.529412
# 215  TABP065   TAB     3        1.0  40.0  NaN  13.0  1.0  0.0  0.000000
# 216  TABP064   TAB     1        1.0  49.0  0.0  13.0  1.0  1.0  0.187500
# 217  TABP064   TAB     2        1.0  50.0  NaN   NaN  1.0  0.0  0.000000
# 218  TABP064   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 219  TABP068   TAB     1        1.0  28.0  1.0  12.0  1.0  1.0  3.500000
# 220  TABP068   TAB     2        1.0  29.0  NaN   NaN  1.0  0.0  0.000000
# 221  TABP068   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 222  TABP076   TAB     1        1.0  20.0  1.0  11.0  1.0  1.0  1.500000
# 223  TABP076   TAB     2        1.0  21.0  NaN   NaN  1.0  0.0  0.333333
# 224  TABP076   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 225  TABP072   TAB     1        1.0  27.0  1.0   7.0  1.0  1.0  0.227273
# 226  TABP072   TAB     2        1.0  28.0  NaN   NaN  1.0  0.0  0.043478
# 227  TABP072   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 228  TABP071   TAB     1        2.0  34.0  0.0  11.0  2.0  0.0  0.500000
# 229  TABP071   TAB     2        2.0  35.0  NaN   NaN  2.0  0.0  0.058824
# 230  TABP071   TAB     3        2.0  41.0  NaN  13.0  2.0  0.0  0.391304
# 231  TABP077   TAB     1        1.0  30.0  1.0  14.0  1.0  0.0  1.555556
# 232  TABP077   TAB     2        1.0  30.0  NaN   NaN  1.0  0.0  0.000000
# 233  TABP077   TAB     3        1.0  36.0  NaN  15.0  1.0  1.0  0.266667
# 234  TABP081   TAB     1        2.0  33.0  0.0   4.0  2.0  0.0  0.909091
# 235  TABP081   TAB     2        2.0  25.0  NaN   NaN  2.0  0.0  0.000000
# 236  TABP081   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 237  TABP084   TAB     1        1.0  26.0  1.0   5.0  1.0  1.0  0.800000
# 238  TABP084   TAB     2        1.0  27.0  NaN   NaN  1.0  0.0  0.000000
# 239  TABP084   TAB     3        1.0  33.0  NaN   5.0  1.0  0.0  0.117647
# 240  TABP082   TAB     1        1.0  48.0  0.0  17.0  1.0  0.0  0.200000
# 241  TABP082   TAB     2        1.0  49.0  NaN   NaN  1.0  0.0  0.000000
# 242  TABP082   TAB     3        1.0  54.0  NaN  22.0  1.0  1.0  0.047619
# 243  TABP079   TAB     1        2.0  32.0  0.0  13.0  1.0  0.0  2.000000
# 244  TABP079   TAB     2        2.0  33.0  NaN   NaN  1.0  0.0  0.000000
# 245  TABP079   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 246  TABP078   TAB     1        1.0  30.0  0.0  17.0  2.0  0.0  0.312500
# 247  TABP078   TAB     2        1.0  31.0  NaN  17.0  2.0  0.0  0.058824
# 248  TABP078   TAB     3        1.0  37.0  NaN  18.0  2.0  1.0  0.869565
# 249  TABP085   TAB     1        2.0  28.0  0.0  13.0  1.0  0.0  1.857143
# 250  TABP085   TAB     2        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 251  TABP085   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 252  TABP087   TAB     1        2.0  27.0  1.0  13.0  1.0  0.0  2.384615
# 253  TABP087   TAB     2        2.0  28.0  NaN   NaN  1.0  0.0  0.000000
# 254  TABP087   TAB     3        2.0  34.0  NaN  13.0  1.0  0.0  0.150000
# 255  TABP091   TAB     1        2.0  32.0  0.0  11.0  1.0  0.0  1.750000
# 256  TABP091   TAB     2        2.0  33.0  NaN   NaN  1.0  0.0  0.058824
# 257  TABP091   TAB     3        2.0  39.0  NaN  11.0  1.0  1.0  0.173913
# 258  TABP092   TAB     1        2.0  24.0  1.0  15.0  1.0  1.0  0.333333
# 259  TABP092   TAB     2        2.0  25.0  NaN   NaN  1.0  0.0  0.000000
# 260  TABP092   TAB     3        2.0   NaN  NaN   NaN  NaN  NaN       NaN
# 261  TABP093   TAB     1        1.0  42.0  0.0  14.0  1.0  1.0  0.550000
# 262  TABP093   TAB     2        1.0  43.0  NaN   NaN  1.0  0.0  0.000000
# 263  TABP093   TAB     3        1.0  48.0  NaN  17.0  1.0  1.0  0.076923
# 264  TABP094   TAB     1        1.0  43.0  0.0   6.0  2.0  0.0  0.482759
# 265  TABP094   TAB     2        1.0  43.0  NaN   NaN  2.0  0.0  0.068966
# 266  TABP094   TAB     3        1.0   NaN  NaN   NaN  NaN  NaN       NaN
# 267  TABP095   TAB     1        2.0  21.0  1.0  13.0  1.0  0.0  2.000000
# 268  TABP095   TAB     2        2.0  21.0  NaN   NaN  1.0  0.0  0.000000
# 269  TABP095   TAB     3        2.0  27.0  NaN  14.0  1.0  0.0  0.250000
# 270  TABP090   TAB     1        2.0  54.0  0.0   5.0  1.0  0.0  0.400000
# 271  TABP090   TAB     2        2.0   NaN  NaN   NaN  NaN  NaN       NaN
#
# 2      prisma3    TAB-prisma3
# 3      prisma1    TAB-prisma1
# 4      prisma2    TAB-prisma2
# 5      prisma3    TAB-prisma3
# 6      prisma1    TAB-prisma1
# 7      prisma2    TAB-prisma2
# 8      prisma3    TAB-prisma3
# 9      prisma1    TAB-prisma1
# 10     prisma2    TAB-prisma2
# 11     prisma3    TAB-prisma3
# 12     prisma1    TAB-prisma1
# 13     prisma2    TAB-prisma2
# 14     prisma3    TAB-prisma3
# 15     prisma1    TAB-prisma1
# 16     prisma2    TAB-prisma2
# 17     prisma3    TAB-prisma3
# 18     prisma1    TAB-prisma1
# 19     prisma2    TAB-prisma2
# 20     prisma3    TAB-prisma3
# 21     prisma1    TAB-prisma1
# 22     prisma2    TAB-prisma2
# 23     prisma3    TAB-prisma3
# 24     prisma1    TAB-prisma1
# 25     prisma2    TAB-prisma2
# 26     prisma3    TAB-prisma3
# 27     prisma1    TAB-prisma1
# 28     prisma2    TAB-prisma2
# 29     prisma3    TAB-prisma3
# 30     prisma1    TAB-prisma1
# 31     prisma2    TAB-prisma2
# 32     prisma3    TAB-prisma3
# 33     prisma1    TAB-prisma1
# 34     prisma2    TAB-prisma2
# 35     prisma3    TAB-prisma3
# 36     prisma1    TAB-prisma1
# 37     prisma2    TAB-prisma2
# 38     prisma3    TAB-prisma3
# 39     prisma1    TAB-prisma1
# 40     prisma2    TAB-prisma2
# 41     prisma3    TAB-prisma3
# 42     prisma1    TAB-prisma1
# 43     prisma2    TAB-prisma2
# 44     prisma3    TAB-prisma3
# 45     prisma1    TAB-prisma1
# 46     prisma2    TAB-prisma2
# 47     prisma3    TAB-prisma3
# 48     prisma1    TAB-prisma1
# 49     prisma2    TAB-prisma2
# 50     prisma3    TAB-prisma3
# 51     prisma1    TAB-prisma1
# 52     prisma2    TAB-prisma2
# 53     prisma3    TAB-prisma3
# 54     prisma1    TAB-prisma1
# 55     prisma2    TAB-prisma2
# 56     prisma3    TAB-prisma3
# 57     prisma1    TAB-prisma1
# 58     prisma2    TAB-prisma2
# 59     prisma3    TAB-prisma3
# 60     prisma1    TAB-prisma1
# 61     prisma2    TAB-prisma2
# 62     prisma3    TAB-prisma3
# 63     prisma1    TAB-prisma1
# 64     prisma2    TAB-prisma2
# 65     prisma3    TAB-prisma3
# 66     prisma1    TAB-prisma1
# 67     prisma2    TAB-prisma2
# 68     prisma3    TAB-prisma3
# 69     prisma1    TAB-prisma1
# 70     prisma2    TAB-prisma2
# 71     prisma3    TAB-prisma3
# 72     prisma1    TAB-prisma1
# 73     prisma2    TAB-prisma2
# 74     prisma3    TAB-prisma3
# 75     prisma1    TAB-prisma1
# 76     prisma2    TAB-prisma2
# 77     prisma3    TAB-prisma3
# 78     prisma1    TAB-prisma1
# 79     prisma2    TAB-prisma2
# 80     prisma3    TAB-prisma3
# 81     prisma1    TAB-prisma1
# 82     prisma2    TAB-prisma2
# 83     prisma3    TAB-prisma3
# 84     prisma1    TAB-prisma1
# 85     prisma2    TAB-prisma2
# 86     prisma3    TAB-prisma3
# 87     prisma1    TAB-prisma1
# 88     prisma2    TAB-prisma2
# 89     prisma3    TAB-prisma3
# 90     prisma1    TAB-prisma1
# 91     prisma2    TAB-prisma2
# 92     prisma3    TAB-prisma3
# 93     prisma1    TAB-prisma1
# 94     prisma2    TAB-prisma2
# 95     prisma3    TAB-prisma3
# 96     prisma1    TAB-prisma1
# 97     prisma2    TAB-prisma2
# 98     prisma3    TAB-prisma3
# 99     prisma1    TAB-prisma1
# 100    prisma2    TAB-prisma2
# 101    prisma3    TAB-prisma3
# 102    prisma1    TAB-prisma1
# 103    prisma2    TAB-prisma2
# 104    prisma3    TAB-prisma3
# 105    prisma1    TAB-prisma1
# 106    prisma2    TAB-prisma2
# 107    prisma3    TAB-prisma3
# 108    prisma1    TAB-prisma1
# 109    prisma2    TAB-prisma2
# 110    prisma3    TAB-prisma3
# 111    prisma1    TAB-prisma1
# 112    prisma2    TAB-prisma2
# 113    prisma3    TAB-prisma3
# 114    prisma1    TAB-prisma1
# 115    prisma2    TAB-prisma2
# 116    prisma3    TAB-prisma3
# 117    prisma1    TAB-prisma1
# 118    prisma2    TAB-prisma2
# 119    prisma3    TAB-prisma3
# 120    prisma1    TAB-prisma1
# 121    prisma2    TAB-prisma2
# 122    prisma3    TAB-prisma3
# 123    prisma1    TAB-prisma1
# 124    prisma2    TAB-prisma2
# 125    prisma3    TAB-prisma3
# 126    prisma1    TAB-prisma1
# 127    prisma2    TAB-prisma2
# 128    prisma3    TAB-prisma3
# 129    prisma1    TAB-prisma1
# 130    prisma2    TAB-prisma2
# 131    prisma3    TAB-prisma3
# 132    prisma1    TAB-prisma1
# 133    prisma2    TAB-prisma2
# 134    prisma3    TAB-prisma3
# 135    prisma1    TAB-prisma1
# 136    prisma2    TAB-prisma2
# 137    prisma3    TAB-prisma3
# 138    prisma1    TAB-prisma1
# 139    prisma2    TAB-prisma2
# 140    prisma3    TAB-prisma3
# 141    prisma1    TAB-prisma1
# 142    prisma2    TAB-prisma2
# 143    prisma3    TAB-prisma3
# 144    prisma1    TAB-prisma1
# 145    prisma2    TAB-prisma2
# 146    prisma3    TAB-prisma3
# 147    prisma1    TAB-prisma1
# 148    prisma2    TAB-prisma2
# 149    prisma3    TAB-prisma3
# 150    prisma1    TAB-prisma1
# 151    prisma2    TAB-prisma2
# 152    prisma3    TAB-prisma3
# 153    prisma1    TAB-prisma1
# 154    prisma2    TAB-prisma2
# 155    prisma3    TAB-prisma3
# 156    prisma1    TAB-prisma1
# 157    prisma2    TAB-prisma2
# 158    prisma3    TAB-prisma3
# 159    prisma1    TAB-prisma1
# 160    prisma2    TAB-prisma2
# 161    prisma3    TAB-prisma3
# 162    prisma1    TAB-prisma1
# 163    prisma2    TAB-prisma2
# 164    prisma3    TAB-prisma3
# 165    prisma1    TAB-prisma1
# 166    prisma2    TAB-prisma2
# 167    prisma3    TAB-prisma3
# 168    prisma1    TAB-prisma1
# 169    prisma2    TAB-prisma2
# 170    prisma3    TAB-prisma3
# 171    prisma1    TAB-prisma1
# 172    prisma2    TAB-prisma2
# 173    prisma3    TAB-prisma3
# 174    prisma1    TAB-prisma1
# 175    prisma2    TAB-prisma2
# 176    prisma3    TAB-prisma3
# 177    prisma1    TAB-prisma1
# 178    prisma2    TAB-prisma2
# 179    prisma3    TAB-prisma3
# 180    prisma1    TAB-prisma1
# 181    prisma2    TAB-prisma2
# 182    prisma3    TAB-prisma3
# 183    prisma1    TAB-prisma1
# 184    prisma2    TAB-prisma2
# 185    prisma3    TAB-prisma3
# 186    prisma1    TAB-prisma1
# 187    prisma2    TAB-prisma2
# 188    prisma3    TAB-prisma3
# 189    prisma1    TAB-prisma1
# 190    prisma2    TAB-prisma2
# 191    prisma3    TAB-prisma3
# 192    prisma1    TAB-prisma1
# 193    prisma2    TAB-prisma2
# 194    prisma3    TAB-prisma3
# 195    prisma1    TAB-prisma1
# 196    prisma2    TAB-prisma2
# 197    prisma3    TAB-prisma3
# 198    prisma1    TAB-prisma1
# 199    prisma2    TAB-prisma2
# 200    prisma3    TAB-prisma3
# 201    prisma1    TAB-prisma1
# 202    prisma2    TAB-prisma2
# 203    prisma3    TAB-prisma3
# 204    prisma1    TAB-prisma1
# 205    prisma2    TAB-prisma2
# 206    prisma3    TAB-prisma3
# 207    prisma1    TAB-prisma1
# 208    prisma2    TAB-prisma2
# 209    prisma3    TAB-prisma3
# 210    prisma1    TAB-prisma1
# 211    prisma2    TAB-prisma2
# 212    prisma3    TAB-prisma3
# 213    prisma1    TAB-prisma1
# 214    prisma2    TAB-prisma2
# 215    prisma3    TAB-prisma3
# 216    prisma1    TAB-prisma1
# 217    prisma2    TAB-prisma2
# 218    prisma3    TAB-prisma3
# 219    prisma1    TAB-prisma1
# 220    prisma2    TAB-prisma2
# 221    prisma3    TAB-prisma3
# 222    prisma1    TAB-prisma1
# 223    prisma2    TAB-prisma2
# 224    prisma3    TAB-prisma3
# 225    prisma1    TAB-prisma1
# 226    prisma2    TAB-prisma2
# 227    prisma3    TAB-prisma3
# 228    prisma1    TAB-prisma1
# 229    prisma2    TAB-prisma2
# 230    prisma3    TAB-prisma3
# 231    prisma1    TAB-prisma1
# 232    prisma2    TAB-prisma2
# 233    prisma3    TAB-prisma3
# 234    prisma1    TAB-prisma1
# 235    prisma2    TAB-prisma2
# 236    prisma3    TAB-prisma3
# 237    prisma1    TAB-prisma1
# 238    prisma2    TAB-prisma2
# 239    prisma3    TAB-prisma3
# 240    prisma1    TAB-prisma1
# 241    prisma2    TAB-prisma2
# 242    prisma3    TAB-prisma3
# 243    prisma1    TAB-prisma1
# 244    prisma2    TAB-prisma2
# 245    prisma3    TAB-prisma3
# 246    prisma1    TAB-prisma1
# 247    prisma2    TAB-prisma2
# 248    prisma3    TAB-prisma3
# 249    prisma1    TAB-prisma1
# 250    prisma2    TAB-prisma2
# 251    prisma3    TAB-prisma3
# 252    prisma1    TAB-prisma1
# 253    prisma2    TAB-prisma2
# 254    prisma3    TAB-prisma3
# 255    prisma1    TAB-prisma1
# 256    prisma2    TAB-prisma2
# 257    prisma3    TAB-prisma3
# 258    prisma1    TAB-prisma1
# 259    prisma2    TAB-prisma2
# 260    prisma3    TAB-prisma3
# 261    prisma1    TAB-prisma1
# 262    prisma2    TAB-prisma2
# 263    prisma3    TAB-prisma3
# 264    prisma1    TAB-prisma1
# 265    prisma2    TAB-prisma2
# 266    prisma3    TAB-prisma3
# 267    prisma1    TAB-prisma1
# 268    prisma2    TAB-prisma2
# 269    prisma3    TAB-prisma3
# 270    prisma1    TAB-prisma1
# 271    prisma2    TAB-prisma2
# 272    prisma3    TAB-prisma3
# 273    prisma1    TAB-prisma1
# 274    prisma2    TAB-prisma2
# 275    prisma3    TAB-prisma3
# 276    prisma1    TAB-prisma1
# 277    prisma2    TAB-prisma2
# 278    prisma3    TAB-prisma3
# 279    prisma1    TAB-prisma1
# 280    prisma2    TAB-prisma2
# 281    prisma3    TAB-prisma3
# 282    prisma1    TAB-prisma1
# 283    prisma2    TAB-prisma2
# 284    prisma3    TAB-prisma3
# 285    prisma1    TAB-prisma1
# 286    prisma2    TAB-prisma2
# 287    prisma3    TAB-prisma3
# 288    prisma1    EQZ-prisma1
# 289    prisma2    EQZ-prisma2
# 290    prisma3    EQZ-prisma3
# 291    prisma1    EQZ-prisma1
# 292    prisma2    EQZ-prisma2
# 293    prisma3    EQZ-prisma3
# 294    prisma1    EQZ-prisma1
# 295    prisma2    EQZ-prisma2
# 296    prisma3    EQZ-prisma3
# 297    prisma1    EQZ-prisma1
# 298    prisma2    EQZ-prisma2
# 299    prisma3    EQZ-prisma3
# 300    prisma1    EQZ-prisma1
# 301    prisma2    EQZ-prisma2
# 302    prisma3    EQZ-prisma3
# 303    prisma1    EQZ-prisma1
# 304    prisma2    EQZ-prisma2
# 305    prisma3    EQZ-prisma3
# 306    prisma1    EQZ-prisma1
# 307    prisma2    EQZ-prisma2
# 308    prisma3    EQZ-prisma3
# 309    prisma1    EQZ-prisma1
# 310    prisma2    EQZ-prisma2
# 311    prisma3    EQZ-prisma3
# 312    prisma1    EQZ-prisma1
# 313    prisma2    EQZ-prisma2
# 314    prisma3    EQZ-prisma3
# 315    prisma1    EQZ-prisma1
# 316    prisma2    EQZ-prisma2
# 317    prisma3    EQZ-prisma3
# 318    prisma1    EQZ-prisma1
# 319    prisma2    EQZ-prisma2
# 320    prisma3    EQZ-prisma3
# 321    prisma1    EQZ-prisma1
# 322    prisma2    EQZ-prisma2
# 323    prisma3    EQZ-prisma3
# 324    prisma1    EQZ-prisma1
# 325    prisma2    EQZ-prisma2
# 326    prisma3    EQZ-prisma3
# 327    prisma1    EQZ-prisma1
# 328    prisma2    EQZ-prisma2
# 329    prisma3    EQZ-prisma3
# 330    prisma1    EQZ-prisma1
# 331    prisma2    EQZ-prisma2
# 332    prisma3    EQZ-prisma3
# 333    prisma1    EQZ-prisma1
# 334    prisma2    EQZ-prisma2
# 335    prisma3    EQZ-prisma3
# 336    prisma1    EQZ-prisma1
# 337    prisma2    EQZ-prisma2
# 338    prisma3    EQZ-prisma3
# 339    prisma1    EQZ-prisma1
# 340    prisma2    EQZ-prisma2
# 341    prisma3    EQZ-prisma3
# 342    prisma1    EQZ-prisma1
# 343    prisma2    EQZ-prisma2
# 344    prisma3    EQZ-prisma3
# 345    prisma1    EQZ-prisma1
# 346    prisma2    EQZ-prisma2
# 347    prisma3    EQZ-prisma3
# 348    prisma1    EQZ-prisma1
# 349    prisma2    EQZ-prisma2
# 350    prisma3    EQZ-prisma3
# 351    prisma1    EQZ-prisma1
# 352    prisma2    EQZ-prisma2
# 353    prisma3    EQZ-prisma3
# 354    prisma1    EQZ-prisma1
# 355    prisma2    EQZ-prisma2
# 356    prisma3    EQZ-prisma3
# 357    prisma1    EQZ-prisma1
# 358    prisma2    EQZ-prisma2
# 359    prisma3    EQZ-prisma3
# 360    prisma1    EQZ-prisma1
# 361    prisma2    EQZ-prisma2
# 362    prisma3    EQZ-prisma3
# 363    prisma1    EQZ-prisma1
# 364    prisma2    EQZ-prisma2
# 365    prisma3    EQZ-prisma3
# 366    prisma1    EQZ-prisma1
# 367    prisma2    EQZ-prisma2
# 368    prisma3    EQZ-prisma3
# 369    prisma1    EQZ-prisma1
# 370    prisma2    EQZ-prisma2
# 371    prisma3    EQZ-prisma3
# 372    prisma1    EQZ-prisma1
# 373    prisma2    EQZ-prisma2
# 374    prisma3    EQZ-prisma3
# 375    prisma1    EQZ-prisma1
# 376    prisma2    EQZ-prisma2
# 377    prisma3    EQZ-prisma3
# 378    prisma1    EQZ-prisma1
# 379    prisma2    EQZ-prisma2
# 380    prisma3    EQZ-prisma3
# 381    prisma1    EQZ-prisma1
# 382    prisma2    EQZ-prisma2
# 383    prisma3    EQZ-prisma3
# 384    prisma1    EQZ-prisma1
# 385    prisma2    EQZ-prisma2
# 386    prisma3    EQZ-prisma3
# 387    prisma1    EQZ-prisma1
# 388    prisma2    EQZ-prisma2
# 389    prisma3    EQZ-prisma3
# 390    prisma1    EQZ-prisma1
# 391    prisma2    EQZ-prisma2
# 392    prisma3    EQZ-prisma3
# 393    prisma1    EQZ-prisma1
# 394    prisma2    EQZ-prisma2
# 395    prisma3    EQZ-prisma3
# 396    prisma1    EQZ-prisma1
# 397    prisma2    EQZ-prisma2
# 398    prisma3    EQZ-prisma3
# 399    prisma1    EQZ-prisma1
# 400    prisma2    EQZ-prisma2
# 401    prisma3    EQZ-prisma3
# 402    prisma1    EQZ-prisma1
# 403    prisma2    EQZ-prisma2
# 404    prisma3    EQZ-prisma3
# 405    prisma1    EQZ-prisma1
# 406    prisma2    EQZ-prisma2
# 407    prisma3    EQZ-prisma3
# 408    prisma1    EQZ-prisma1
# 409    prisma2    EQZ-prisma2
# 410    prisma3    EQZ-prisma3
# 411    prisma1    EQZ-prisma1
# 412    prisma2    EQZ-prisma2
# 413    prisma3    EQZ-prisma3
# 414    prisma1    EQZ-prisma1
# 415    prisma2    EQZ-prisma2
# 416    prisma3    EQZ-prisma3
# 417    prisma1    EQZ-prisma1
# 418    prisma2    EQZ-prisma2
# 419    prisma3    EQZ-prisma3
# 420    prisma1    EQZ-prisma1
# 421    prisma2    EQZ-prisma2
# 422    prisma3    EQZ-prisma3
# 423    prisma1    EQZ-prisma1
# 424    prisma2    EQZ-prisma2
# 425    prisma3    EQZ-prisma3
# 426    prisma1    EQZ-prisma1
# 427    prisma2    EQZ-prisma2
# 428    prisma3    EQZ-prisma3
# 429    prisma1    EQZ-prisma1
# 430    prisma2    EQZ-prisma2
# 431    prisma3    EQZ-prisma3
# 432    prisma1    EQZ-prisma1
# 433    prisma2    EQZ-prisma2
# 434    prisma3    EQZ-prisma3
# 435    prisma1    EQZ-prisma1
# 436    prisma2    EQZ-prisma2
# 437    prisma3    EQZ-prisma3
# 438    prisma1    EQZ-prisma1
# 439    prisma2    EQZ-prisma2
# 440    prisma3    EQZ-prisma3
# 441    prisma1    EQZ-prisma1
# 442    prisma2    EQZ-prisma2
# 443    prisma3    EQZ-prisma3
# 444    prisma1    EQZ-prisma1
# 445    prisma2    EQZ-prisma2
# 446    prisma3    EQZ-prisma3
# 447    prisma1    EQZ-prisma1
# 448    prisma2    EQZ-prisma2
# 449    prisma3    EQZ-prisma3
# 450    prisma1    EQZ-prisma1
# 451    prisma2    EQZ-prisma2
# 452    prisma3    EQZ-prisma3
# 453    prisma1    EQZ-prisma1
# 454    prisma2    EQZ-prisma2
# 455    prisma3    EQZ-prisma3
# 456    prisma1    EQZ-prisma1
# 457    prisma2    EQZ-prisma2
# 458    prisma3    EQZ-prisma3
# 459    prisma1    EQZ-prisma1
# 460    prisma2    EQZ-prisma2
# 461    prisma3    EQZ-prisma3
# 462    prisma1    EQZ-prisma1
# 463    prisma2    EQZ-prisma2
# 464    prisma3    EQZ-prisma3
# 465    prisma1    EQZ-prisma1
# 466    prisma2    EQZ-prisma2
# 467    prisma3    EQZ-prisma3
# 468  controles  CTR-controles
# 469  controles  CTR-controles
# 470  controles  CTR-controles
# 471  controles  CTR-controles
# 472  controles  CTR-controles
# 473  controles  CTR-controles
# 474  controles  CTR-controles
# 475  controles  CTR-controles
# 476  controles  CTR-controles
# 477  controles  CTR-controles
# 478  controles  CTR-controles
# 479  controles  CTR-controles
# 480  controles  CTR-controles
# 481  controles  CTR-controles
# 482  controles  CTR-controles
# 483  controles  CTR-controles
# 484  controles  CTR-controles
# 485  controles  CTR-controles
# 486  controles  CTR-controles
# 487  controles  CTR-controles
# 488  controles  CTR-controles
# 489  controles  CTR-controles
# 490  controles  CTR-controles
# 491  controles  CTR-controles
# 492  controles  CTR-controles
# 493  controles  CTR-controles
# 494  controles  CTR-controles
# 495  controles  CTR-controles

# %% [markdown]
# ## Merge both files

# %%
clinical_image_df= pd.merge(all_data, clinical_data_f[['subject','project','c_group','treatment','psc','dx','Gravedad','edad']], how='left', on=['subject', 'project'])

#Remove data for TAB and diagnosis 2
clinical_image_df.drop(clinical_image_df.index[(clinical_image_df.subject.str.contains('TAB'))&(clinical_image_df.dx==2)],inplace=True)

# Remove subject with NAs in volumetric nan
#clinical_image_df.drop(clinical_image_df.index[clinical_image_df.subject=="TABP079"],inplace=True)

# %%
#clinical_image_df

# %%
clinical_image_df[clinical_image_df['subject']=='TABP079']
# Remove subject with NAs in volumetric and clinical data
clinical_image_df.drop(clinical_image_df.index[clinical_image_df.subject=="TABP079"],inplace=True)

# %% [markdown]
# ### NORMALIZE BY GROUP

# %% [markdown]
# ## Standardscaler

# %%
# Standardize features by removing the mean and scaling to unit variance
clinical_image_df_n_CTR= clinical_image_df[clinical_image_df.grupo=='CTR']
clinical_image_df_n_EQF= clinical_image_df[clinical_image_df.grupo=='EQF']
clinical_image_df_n_TAB= clinical_image_df[clinical_image_df.grupo=='TAB']
clinical_image_df_n_CTR.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_CTR.iloc[:,4:-6])
clinical_image_df_n_TAB.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_TAB.iloc[:,4:-6])
clinical_image_df_n_EQF.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_EQF.iloc[:,4:-6])
# Out:
# /var/folders/wp/_tyy4sn10dn9tbjvll8p76m80000gr/T/ipykernel_30892/4211913440.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_image_df_n_CTR.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_CTR.iloc[:,4:-6])
# /var/folders/wp/_tyy4sn10dn9tbjvll8p76m80000gr/T/ipykernel_30892/4211913440.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_image_df_n_TAB.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_TAB.iloc[:,4:-6])
# /var/folders/wp/_tyy4sn10dn9tbjvll8p76m80000gr/T/ipykernel_30892/4211913440.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_image_df_n_EQF.iloc[:,4:-6] = preprocessing.StandardScaler().fit_transform(clinical_image_df_n_EQF.iloc[:,4:-6])

# %% [markdown]
# ## Z-score by subject

# %%
# Normalización z-score por fila (sujeto)
clinical_image_z = clinical_image_df
clinical_image_z.iloc[:,4:-6] = clinical_image_z.iloc[:,4:-6].apply(zscore, axis=1)

# %%
clinical_image_n = pd.concat([clinical_image_df_n_CTR,clinical_image_df_n_TAB,clinical_image_df_n_EQF])

# %%
#clinical_image_i = clinical_image_z # Selección normalización por z-score
clinical_image_i = clinical_image_n # Selección normalización por grupo
clinical_image_EQF = clinical_image_i[clinical_image_i.grupo!='TAB'] # Toma EQF y CTRL
clinical_image_TAB = clinical_image_i[clinical_image_i.grupo!='EQF'] # Toma TAB y CTRL

# %%
# Formación datos EQF y TAB --> PSI
clinical_image_i['grupo-p'] = ''
clinical_image_i.loc[clinical_image_i.grupo.str.contains('TAB'), 'grupo-p'] = 'PSI'
clinical_image_i.loc[clinical_image_i.grupo.str.contains('EQF'), 'grupo-p'] = 'PSI'
clinical_image_i.loc[clinical_image_i.grupo.str.contains('CTR'), 'grupo-p'] = 'CTR'
# Modificar condición
#clinical_image_i['c_group'] = clinical_image_i['grupo'] + '-' + clinical_image_i['project'] +'-' +'treatment' + clinical_image_i['treatment'].astype(str)
clinical_image_i['c_group'] = clinical_image_i['grupo-p'] + '-' + clinical_image_i['project'] + '-' + clinical_image_i['grupo']

# %%
clinical_image_i
# Out:
#      subject grupo    project  Brain Segmentation Volume  \
# 0    CTRL028   CTR  controles                   0.829100
# 1    CTRL020   CTR  controles                   0.798626
# 2    CTRL027   CTR  controles                   0.847668
# 3    CTRL026   CTR  controles                   0.802878
# 4    CTRL021   CTR  controles                   0.788088
# 5    CTRL023   CTR  controles                   0.863998
# 6    CTRL024   CTR  controles                   0.788900
# 7    CTRL025   CTR  controles                   0.909704
# 8    CTRL022   CTR  controles                   0.797424
# 9    CTRL016   CTR  controles                   0.776614
# 10   CTRL003   CTR  controles                   0.903079
# 11   CTRL019   CTR  controles                   0.920915
# 12   CTRL004   CTR  controles                   0.830933
# 13   CTRL011   CTR  controles                   0.819866
# 14   CTRL010   CTR  controles                   0.818588
# 15   CTRL005   CTR  controles                   0.854956
# 16   CTRL018   CTR  controles                   0.832232
# 17   CTRL002   CTR  controles                   0.837630
# 18   CTRL017   CTR  controles                   0.824697
# 19   CTRL015   CTR  controles                   0.822326
# 20   CTRL008   CTR  controles                   0.828134
# 21   CTRL012   CTR  controles                   0.752690
# 22   CTRL007   CTR  controles                   0.822284
# 23   CTRL006   CTR  controles                   0.833441
# 24   CTRL013   CTR  controles                   0.833478
# 25   CTRL009   CTR  controles                   0.831937
# 26   CTRL014   CTR  controles                   0.844825
# 27   CTRL001   CTR  controles                   0.799991
# 28   TABP030   TAB    prisma1                   0.795703
# 29   TABP025   TAB    prisma1                   0.803588
# 32   TABP054   TAB    prisma1                   0.761229
# 33   TABP041   TAB    prisma1                   0.756481
# 35   TABP049   TAB    prisma1                   0.796316
# 38   TABP022   TAB    prisma1                   0.817109
# 39   TABP037   TAB    prisma1                   0.742349
# 40   TABP046   TAB    prisma1                   0.781423
# 44   TABP036   TAB    prisma1                   0.803949
# 45   TABP023   TAB    prisma1                   0.756056
# 47   TABP052   TAB    prisma1                   0.763246
# 48   TABP047   TAB    prisma1                   0.809569
# 49   TABP048   TAB    prisma1                   0.888275
# 53   TABP024   TAB    prisma1                   0.825161
# 56   TABP040   TAB    prisma1                   0.777847
# 57   TABP055   TAB    prisma1                   0.817742
# 60   TABP057   TAB    prisma1                   0.785724
# 63   TABP026   TAB    prisma1                   0.760666
# 64   TABP033   TAB    prisma1                   0.784473
# 65   TABP029   TAB    prisma1                   0.748000
# 66   TABP058   TAB    prisma1                   0.739914
# 67   TABP045   TAB    prisma1                   0.780749
# 68   TABP034   TAB    prisma1                   0.807007
# 69   TABP021   TAB    prisma1                   0.774835
# 71   TABP044   TAB    prisma1                   0.813915
# 75   TABP020   TAB    prisma1                   0.741611
# 76   TABP035   TAB    prisma1                   0.772316
# 77   TABP059   TAB    prisma1                   0.761797
# 79   TABP043   TAB    prisma1                   0.899731
# 81   TABP032   TAB    prisma1                   0.787563
# 82   TABP027   TAB    prisma1                   0.749953
# 88   TABP062   TAB    prisma1                   0.817319
# 89   TABP077   TAB    prisma1                   0.773660
# 92   TABP013   TAB    prisma1                   0.818272
# 94   TABP095   TAB    prisma1                   0.803665
# 95   TABP080   TAB    prisma1                   0.790821
# 97   TABP070   TAB    prisma1                   0.752227
# 98   TABP065   TAB    prisma1                   0.817362
# 100  TABP014   TAB    prisma1                   0.742105
# 101  TABP001   TAB    prisma1                   0.988651
# 104  TABP087   TAB    prisma1                   0.823882
# 105  TABP092   TAB    prisma1                   0.799057
# 106  TABP009   TAB    prisma1                   0.776301
# 108  TABP008   TAB    prisma1                   0.794056
# 109  TABP093   TAB    prisma1                   0.813890
# 110  TABP086   TAB    prisma1                   0.795305
# 117  TABP015   TAB    prisma1                   0.764051
# 122  TABP076   TAB    prisma1                   0.810945
# 123  TABP063   TAB    prisma1                   0.795648
# 126  TABP012   TAB    prisma1                   0.804798
# 127  TABP007   TAB    prisma1                   0.749197
# 130  TABP089   TAB    prisma1                   0.762182
# 131  TABP069   TAB    prisma1                   0.803690
# 132  TABP018   TAB    prisma1                   0.766310
# 133  TABP083   TAB    prisma1                   0.798735
# 134  TABP096   TAB    prisma1                   0.756027
# 135  TABP010   TAB    prisma1                   0.786799
# 136  TABP005   TAB    prisma1                   0.760974
# 139  TABP074   TAB    prisma1                   0.759888
# 140  TABP061   TAB    prisma1                   0.803533
# 144  TABP091   TAB    prisma1                   0.792340
# 145  TABP084   TAB    prisma1                   0.808186
# 149  TABP017   TAB    prisma1                   0.840472
# 152  TABP066   TAB    prisma1                   0.785034
# 153  TABP073   TAB    prisma1                   0.772325
# 154  TABP016   TAB    prisma1                   0.791251
# 155  TABP003   TAB    prisma1                   0.876849
# 158  TABP072   TAB    prisma1                   0.871963
# 159  TABP067   TAB    prisma1                   0.864560
# 163  TABP085   TAB    prisma1                   0.779877
# 164  TABP090   TAB    prisma1                   0.757788
# 166  TABP004   TAB    prisma1                   0.823174
# 167  TABP011   TAB    prisma1                   0.778344
# 169  TABP060   TAB    prisma1                   0.795265
# 170  TABP068   TAB    prisma1                   0.773150
# 171  TABP082   TAB    prisma1                   0.808799
# 172  TABP019   TAB    prisma1                   0.698524
# 173  TABP057   TAB    prisma3                   0.799077
# 174  TABP026   TAB    prisma3                   0.753380
# 178  TABP021   TAB    prisma3                   0.783465
# 179  TABP058   TAB    prisma3                   0.709537
# 180  TABP044   TAB    prisma3                   0.816722
# 181  TABP020   TAB    prisma3                   0.702156
# 182  TABP035   TAB    prisma3                   0.769247
# 184  TABP043   TAB    prisma3                   0.937391
# 187  TABP030   TAB    prisma3                   0.760635
# 188  TABP025   TAB    prisma3                   0.767205
# 189  TABP054   TAB    prisma3                   0.741100
# 190  TABP041   TAB    prisma3                   0.764480
# 192  TABP022   TAB    prisma3                   0.784831
# 193  TABP037   TAB    prisma3                   0.798037
# 198  TABP036   TAB    prisma3                   0.828011
# 199  TABP052   TAB    prisma3                   0.772627
# 200  TABP047   TAB    prisma3                   0.812016
# 202  TABP024   TAB    prisma3                   0.835235
# 204  TABP040   TAB    prisma3                   0.767459
# 205  TABP055   TAB    prisma3                   0.818537
# 207  TABP048   TAB    prisma3                   0.904700
# 208  TABP005   TAB    prisma3                   0.749957
# 209  TABP074   TAB    prisma3                   0.792162
# 210  TABP061   TAB    prisma3                   0.811943
# 211  TABP069   TAB    prisma3                   0.763842
# 212  TABP018   TAB    prisma3                   0.752651
# 213  TABP017   TAB    prisma3                   0.819484
# 215  TABP101   TAB    prisma3                   0.755613
# 216  TABP073   TAB    prisma3                   0.749122
# 218  TABP091   TAB    prisma3                   0.796113
# 220  TABP085   TAB    prisma3                   0.778597
# 221  TABP090   TAB    prisma3                   0.747112
# 222  TABP100   TAB    prisma3                   0.766991
# 223  TABP003   TAB    prisma3                   0.829875
# 224  TABP072   TAB    prisma3                   0.869885
# 225  TABP067   TAB    prisma3                   0.859317
# 226  TABP068   TAB    prisma3                   0.775809
# 227  TABP082   TAB    prisma3                   0.765510
# 229  TABP060   TAB    prisma3                   0.788463
# 232  TABP095   TAB    prisma3                   0.776747
# 234  TABP077   TAB    prisma3                   0.854495
# 237  TABP105   TAB    prisma3                   0.820247
# 240  TABP092   TAB    prisma3                   0.780237
# 243  TABP070   TAB    prisma3                   0.727016
# 244  TABP065   TAB    prisma3                   0.790956
# 246  TABP001   TAB    prisma3                   0.727338
# 247  TABP102   TAB    prisma3                   0.790773
# 251  TABP103   TAB    prisma3                   0.811624
# 253  TABP093   TAB    prisma3                   0.862555
# 254  TABP086   TAB    prisma3                   0.812335
# 257  TABP012   TAB    prisma3                   0.803860
# 258  TABP007   TAB    prisma3                   0.741454
# 259  TABP104   TAB    prisma3                   0.779844
# 30   EQFP006   EQF    prisma1                   0.699723
# 31   EQFP013   EQF    prisma1                   0.799324
# 34   EQFP062   EQF    prisma1                   0.777590
# 36   EQFP014   EQF    prisma1                   0.812468
# 37   EQFP001   EQF    prisma1                   0.762410
# 42   EQFP009   EQF    prisma1                   0.786427
# 43   EQFP008   EQF    prisma1                   0.803710
# 46   EQFP015   EQF    prisma1                   0.790628
# 51   EQFP012   EQF    prisma1                   0.821875
# 52   EQFP007   EQF    prisma1                   0.792350
# 55   EQFP063   EQF    prisma1                   0.814436
# 58   EQFP018   EQF    prisma1                   0.751076
# 59   EQFP061   EQF    prisma1                   0.802623
# 61   EQFP010   EQF    prisma1                   0.821621
# 62   EQFP005   EQF    prisma1                   0.826999
# 70   EQFP017   EQF    prisma1                   0.807428
# 73   EQFP016   EQF    prisma1                   0.812203
# 74   EQFP003   EQF    prisma1                   0.835735
# 80   EQFP060   EQF    prisma1                   0.760145
# 83   EQFP004   EQF    prisma1                   0.755929
# 84   EQFP011   EQF    prisma1                   0.747196
# 85   EQFP019   EQF    prisma1                   0.750678
# 86   EQFP054   EQF    prisma1                   0.777684
# 87   EQFP041   EQF    prisma1                   0.800378
# 90   EQFP030   EQF    prisma1                   0.774317
# 91   EQFP025   EQF    prisma1                   0.721324
# 93   EQFP038   EQF    prisma1                   0.725169
# 96   EQFP049   EQF    prisma1                   0.797341
# 99   EQFP053   EQF    prisma1                   0.783070
# 102  EQFP022   EQF    prisma1                   0.769126
# 103  EQFP037   EQF    prisma1                   0.802419
# 112  EQFP052   EQF    prisma1                   0.735780
# 113  EQFP047   EQF    prisma1                   0.826932
# 115  EQFP036   EQF    prisma1                   0.803173
# 116  EQFP023   EQF    prisma1                   0.780668
# 120  EQFP039   EQF    prisma1                   0.755119
# 121  EQFP048   EQF    prisma1                   0.742568
# 124  EQFP040   EQF    prisma1                   0.846091
# 125  EQFP055   EQF    prisma1                   0.805659
# 128  EQFP024   EQF    prisma1                   0.825529
# 129  EQFP031   EQF    prisma1                   0.810519
# 137  EQFP026   EQF    prisma1                   0.793155
# 138  EQFP033   EQF    prisma1                   0.855939
# 141  EQFP042   EQF    prisma1                   0.755909
# 142  EQFP057   EQF    prisma1                   0.756353
# 143  EQFP058   EQF    prisma1                   0.840899
# 146  EQFP029   EQF    prisma1                   0.851291
# 147  EQFP034   EQF    prisma1                   0.773004
# 148  EQFP021   EQF    prisma1                   0.742988
# 150  EQFP050   EQF    prisma1                   0.783086
# 151  EQFP045   EQF    prisma1                   0.725983
# 156  EQFP020   EQF    prisma1                   0.816813
# 157  EQFP035   EQF    prisma1                   0.826284
# 160  EQFP051   EQF    prisma1                   0.779980
# 161  EQFP059   EQF    prisma1                   0.764492
# 162  EQFP028   EQF    prisma1                   0.813313
# 165  EQFP027   EQF    prisma1                   0.776257
# 168  EQFP056   EQF    prisma1                   0.774714
# 175  EQFP005   EQF    prisma3                   0.817362
# 176  EQFP018   EQF    prisma3                   0.752191
# 177  EQFP017   EQF    prisma3                   0.820605
# 183  EQFP019   EQF    prisma3                   0.707661
# 185  EQFP004   EQF    prisma3                   0.730134
# 186  EQFP011   EQF    prisma3                   0.741019
# 191  EQFP009   EQF    prisma3                   0.780249
# 194  EQFP014   EQF    prisma3                   0.828016
# 195  EQFP001   EQF    prisma3                   0.782678
# 196  EQFP070   EQF    prisma3                   0.784552
# 197  EQFP015   EQF    prisma3                   0.770273
# 201  EQFP008   EQF    prisma3                   0.810234
# 203  EQFP012   EQF    prisma3                   0.772556
# 206  EQFP063   EQF    prisma3                   0.774019
# 214  EQFP021   EQF    prisma3                   0.778639
# 217  EQFP045   EQF    prisma3                   0.775082
# 219  EQFP059   EQF    prisma3                   0.734130
# 228  EQFP027   EQF    prisma3                   0.755077
# 230  EQFP056   EQF    prisma3                   0.768825
# 231  EQFP043   EQF    prisma3                   0.746742
# 233  EQFP049   EQF    prisma3                   0.880567
# 235  EQFP054   EQF    prisma3                   0.763214
# 236  EQFP041   EQF    prisma3                   0.787632
# 238  EQFP030   EQF    prisma3                   0.761657
# 239  EQFP025   EQF    prisma3                   0.799558
# 241  EQFP046   EQF    prisma3                   0.834931
# 242  EQFP053   EQF    prisma3                   0.768893
# 245  EQFP037   EQF    prisma3                   0.806223
# 249  EQFP052   EQF    prisma3                   0.774604
# 250  EQFP047   EQF    prisma3                   0.822751
# 252  EQFP036   EQF    prisma3                   0.788112
# 256  EQFP055   EQF    prisma3                   0.800666
# 260  EQFP039   EQF    prisma3                   0.772165
#
#      Brain Segmentation Volume Without Ventricles  \
# 0                                       -0.033752
# 1                                       -0.900882
# 2                                        0.613231
# 3                                       -0.703795
# 4                                       -1.350691
# 5                                        1.034252
# 6                                       -0.994075
# 7                                        2.092513
# 8                                       -0.889892
# 9                                       -1.257580
# 10                                       1.840037
# 11                                       2.515016
# 12                                       0.125173
# 13                                      -0.489261
# 14                                      -0.249173
# 15                                       0.794139
# 16                                       0.048933
# 17                                       0.182975
# 92                                     -0.299910
# 94                                      0.341472
# 95                                     -0.168104
# 97                                     -0.640311
# 98                                      0.135278
# 100                                    -1.011429
# 101                                     4.496290
# 104                                     0.347147
# 105                                     0.154637
# 106                                    -0.368580
# 108                                    -0.213210
# 109                                     1.073364
# 110                                     0.176424
# 117                                    -0.172011
# 122                                     0.674088
# 123                                     0.147387
# 126                                     0.346988
# 127                                    -1.701654
# 130                                    -0.618306
# 131                                     1.307440
# 132                                    -0.622322
# 133                                    -0.103356
# 134                                    -0.030059
# 135                                    -0.064832
# 136                                    -1.281348
# 139                                    -0.940462
# 140                                     0.688007
# 144                                     0.129692
# 145                                    -0.125287
# 149                                     0.287878
# 152                                    -0.792194
# 153                                    -0.758573
# 154                                    -0.480986
# 155                                     1.891790
# 158                                     1.184356
# 159                                     0.844108
# 163                                    -0.350447
# 164                                    -1.066646
# 166                                     0.708890
# 167                                    -0.744027
# 169                                    -0.001226
# 170                                    -0.643505
# 171                                     0.393921
# 172                                    -2.235899
# 173                                    -0.686861
# 174                                    -0.424394
# 178                                     0.782388
# 179                                    -1.932126
# 180                                     0.878672
# 181                                    -1.529256
# 182                                    -0.398830
# 184                                     3.126417
# 187                                    -0.489489
# 188                                    -0.035455
# 189                                    -0.147382
# 190                                    -0.110264
# 192                                    -0.962411
# 193                                     0.997013
# 198                                     1.086484
# 199                                    -1.175803
# 200                                     1.387385
# 202                                     0.963844
# 204                                    -0.583927
# 205                                     0.268084
# 207                                     2.206284
# 208                                    -0.837745
# 209                                    -0.187691
# 210                                     0.948627
# 211                                     0.213978
# 212                                    -0.728259
# 213                                    -0.249688
# 215                                    -0.564984
# 216                                    -0.879918
# 218                                     0.397192
# 220                                    -0.215898
# 221                                    -0.017766
# 222                                    -1.069138
# 223                                     0.604769
# 224                                     1.286518
# 225                                     0.628192
# 226                                    -0.537767
# 227                                    -0.746655
# 229                                    -0.382931
# 232                                    -0.560086
# 234                                     1.615947
# 237                                     0.662357
# ...
# 222                 -0.566135    PSI-prisma3-TAB        1.0  0.0  1.0
# 223                  0.191737    PSI-prisma3-TAB        1.0  NaN  NaN
# 224                  1.409661    PSI-prisma3-TAB        1.0  NaN  NaN
# 225                 -0.005721    PSI-prisma3-TAB        1.0  NaN  1.0
# 226                 -0.834980    PSI-prisma3-TAB        1.0  NaN  NaN
# 227                 -0.261551    PSI-prisma3-TAB        1.0  1.0  1.0
# 229                 -0.089932    PSI-prisma3-TAB        1.0  0.0  1.0
# 232                  0.039113    PSI-prisma3-TAB        2.0  0.0  1.0
# 234                 -0.025555    PSI-prisma3-TAB        1.0  1.0  1.0
# 237                 -1.032681    PSI-prisma3-TAB        1.0  1.0  1.0
# 240                  0.361792    PSI-prisma3-TAB        2.0  NaN  NaN
# 243                  1.722640    PSI-prisma3-TAB        2.0  1.0  1.0
# 244                  0.822130    PSI-prisma3-TAB        1.0  0.0  1.0
# 246                 -0.028446    PSI-prisma3-TAB        2.0  0.0  1.0
# 247                  1.239498    PSI-prisma3-TAB        2.0  0.0  1.0
# 251                 -0.012336    PSI-prisma3-TAB        1.0  1.0  1.0
# 253                  0.574912    PSI-prisma3-TAB        1.0  1.0  1.0
# 254                 -0.403008    PSI-prisma3-TAB        1.0  0.0  1.0
# 257                  0.081447    PSI-prisma3-TAB        2.0  0.0  1.0
# 258                 -2.201174    PSI-prisma3-TAB        1.0  0.0  1.0
# 259                  0.741333    PSI-prisma3-TAB        2.0  0.0  1.0
# 30                  -1.553848    PSI-prisma1-EQF        1.0  1.0  1.0
# 31                   0.321209    PSI-prisma1-EQF        1.0  1.0  2.0
# 34                   0.541654    PSI-prisma1-EQF        1.0  1.0  1.0
# 36                   0.778123    PSI-prisma1-EQF        2.0  1.0  1.0
# 37                  -0.214208    PSI-prisma1-EQF        1.0  1.0  1.0
# 42                  -0.508983    PSI-prisma1-EQF        1.0  1.0  4.0
# 43                   0.202332    PSI-prisma1-EQF        1.0  1.0  1.0
# 46                  -1.043939    PSI-prisma1-EQF        2.0  1.0  6.0
# 51                   0.048026    PSI-prisma1-EQF        2.0  1.0  1.0
# 52                   0.347030    PSI-prisma1-EQF        NaN  NaN  NaN
# 55                  -0.804977    PSI-prisma1-EQF        1.0  1.0  1.0
# 58                  -0.951487    PSI-prisma1-EQF        1.0  1.0  1.0
# 59                   0.441553    PSI-prisma1-EQF        1.0  1.0  1.0
# 61                   1.452379    PSI-prisma1-EQF        2.0  1.0  1.0
# 62                  -1.659663    PSI-prisma1-EQF        2.0  1.0  1.0
# 70                  -0.723813    PSI-prisma1-EQF        1.0  1.0  1.0
# 73                  -0.418911    PSI-prisma1-EQF        2.0  1.0  3.0
# 74                  -0.677921    PSI-prisma1-EQF        1.0  1.0  1.0
# 80                  -1.442159    PSI-prisma1-EQF        2.0  1.0  5.0
# 83                   0.081334    PSI-prisma1-EQF        2.0  1.0  3.0
# 84                  -0.849237    PSI-prisma1-EQF        1.0  1.0  1.0
# 85                  -0.232144    PSI-prisma1-EQF        1.0  1.0  1.0
# 86                  -0.099919    PSI-prisma1-EQF        1.0  1.0  1.0
# 87                  -1.027353    PSI-prisma1-EQF        1.0  1.0  1.0
# 90                   0.414586    PSI-prisma1-EQF        1.0  1.0  6.0
# 91                  -0.415360    PSI-prisma1-EQF        1.0  1.0  1.0
# 93                  -0.848076    PSI-prisma1-EQF        2.0  1.0  1.0
# 96                   1.445666    PSI-prisma1-EQF        2.0  1.0  1.0
# 99                   2.238141    PSI-prisma1-EQF        2.0  1.0  1.0
# 102                  0.176033    PSI-prisma1-EQF        NaN  1.0  1.0
# 103                 -0.108559    PSI-prisma1-EQF        2.0  1.0  5.0
# 112                  0.958375    PSI-prisma1-EQF        1.0  1.0  1.0
# 113                 -1.474677    PSI-prisma1-EQF        1.0  1.0  2.0
# 115                 -0.924596    PSI-prisma1-EQF        2.0  1.0  1.0
# 116                  0.067075    PSI-prisma1-EQF        1.0  1.0  6.0
# 120                  0.264026    PSI-prisma1-EQF        NaN  1.0  1.0
# 121                 -1.538501    PSI-prisma1-EQF        1.0  1.0  2.0
# 124                  0.933515    PSI-prisma1-EQF        1.0  1.0  1.0
# 125                  1.896514    PSI-prisma1-EQF        1.0  1.0  6.0
# 128                 -0.247723    PSI-prisma1-EQF        2.0  1.0  2.0
# 129                  0.844931    PSI-prisma1-EQF        1.0  1.0  1.0
# 137                 -0.472501    PSI-prisma1-EQF        2.0  1.0  5.0
# 138                  2.289110    PSI-prisma1-EQF        1.0  1.0  1.0
# 141                 -0.073215    PSI-prisma1-EQF        2.0  1.0  1.0
# 142                 -0.784283    PSI-prisma1-EQF        2.0  1.0  1.0
# 143                 -0.737162    PSI-prisma1-EQF        1.0  1.0  1.0
# 146                  0.440166    PSI-prisma1-EQF        1.0  1.0  7.0
# 147                  0.755820    PSI-prisma1-EQF        1.0  1.0  1.0
# 148                  0.012769    PSI-prisma1-EQF        1.0  1.0  1.0
# 150                  0.214660    PSI-prisma1-EQF        1.0  1.0  2.0
# 151                 -0.651968    PSI-prisma1-EQF        1.0  1.0  1.0
# 156                 -0.028884    PSI-prisma1-EQF        NaN  NaN  NaN
# 157                  2.200502    PSI-prisma1-EQF        NaN  NaN  NaN
# 160                 -0.613420    PSI-prisma1-EQF        2.0  1.0  1.0
# 161                 -0.541969    PSI-prisma1-EQF        1.0  1.0  1.0
# 162                  0.000114    PSI-prisma1-EQF        2.0  1.0  1.0
# 165                  0.134659    PSI-prisma1-EQF        1.0  1.0  1.0
# 168                  2.588952    PSI-prisma1-EQF        2.0  1.0  1.0
# 175                 -1.250581    PSI-prisma3-EQF        2.0  0.0  1.0
# 176                 -0.920007    PSI-prisma3-EQF        1.0  0.0  1.0
# 177                 -1.078057    PSI-prisma3-EQF        1.0  0.0  1.0
# 183                  0.181211    PSI-prisma3-EQF        1.0  0.0  1.0
# 185                  0.362101    PSI-prisma3-EQF        2.0  0.0  3.0
# 186                 -0.871758    PSI-prisma3-EQF        1.0  0.0  1.0
# 191                 -0.684428    PSI-prisma3-EQF        1.0  1.0  4.0
# 194                  0.920518    PSI-prisma3-EQF        2.0  NaN  NaN
# 195                  0.991309    PSI-prisma3-EQF        1.0  0.0  1.0
# 196                  0.397365    PSI-prisma3-EQF        2.0  0.0  1.0
# 197                 -1.308347    PSI-prisma3-EQF        2.0  0.0  6.0
# 201                 -0.355920    PSI-prisma3-EQF        1.0  0.0  1.0
# 203                 -0.387029    PSI-prisma3-EQF        2.0  0.0  1.0
# 206                 -0.916039    PSI-prisma3-EQF        1.0  NaN  NaN
# 214                  0.293028    PSI-prisma3-EQF        1.0  0.0  1.0
# 217                 -0.309537    PSI-prisma3-EQF        1.0  0.0  1.0
# 219                 -0.520922    PSI-prisma3-EQF        1.0  1.0  1.0
# 228                 -0.020836    PSI-prisma3-EQF        1.0  0.0  1.0
# 230                  2.262685    PSI-prisma3-EQF        2.0  0.0  1.0
# 231                  0.066134    PSI-prisma3-EQF        2.0  0.0  2.0
# 233                  2.311597    PSI-prisma3-EQF        2.0  NaN  NaN
# 235                  0.210396    PSI-prisma3-EQF        1.0  0.0  1.0
# 236                 -1.241274    PSI-prisma3-EQF        1.0  0.0  1.0
# 238                 -0.322645    PSI-prisma3-EQF        1.0  NaN  NaN
# 239                  0.059015    PSI-prisma3-EQF        1.0  0.0  1.0
# 241                  1.666524    PSI-prisma3-EQF        1.0  1.0  1.0
# 242                  0.397443    PSI-prisma3-EQF        2.0  0.0  1.0
# 245                 -0.929260    PSI-prisma3-EQF        2.0  0.0  5.0
# 249                  1.462401    PSI-prisma3-EQF        1.0  NaN  NaN
# 250                 -1.545430    PSI-prisma3-EQF        1.0  NaN  NaN
# 252                 -1.092722    PSI-prisma3-EQF        2.0  NaN  NaN
# 256                  1.562415    PSI-prisma3-EQF        1.0  0.0  6.0
# 260                  0.190854    PSI-prisma3-EQF        NaN  0.0  1.0
#
#      Gravedad  edad  grupo-p
# 0    0.000000  28.0      CTR
# 1    0.000000  58.0      CTR
# 2    0.000000  41.0      CTR
# 3    0.000000  56.0      CTR
# 4    0.000000  37.0      CTR
# 5    0.000000  28.0      CTR
# 6    0.000000  37.0      CTR
# 7    0.000000  49.0      CTR
# 8    0.000000  67.0      CTR
# 9    0.000000  44.0      CTR
# 10   0.000000  40.0      CTR
# 11   0.000000  31.0      CTR
# 12   0.000000  26.0      CTR
# 13   0.000000  32.0      CTR
# 14   0.000000  33.0      CTR
# 15   0.000000  25.0      CTR
# 16   0.000000  38.0      CTR
# 17   0.000000  44.0      CTR
# 18   0.000000  28.0      CTR
# 19   0.000000  46.0      CTR
# 20   0.000000  27.0      CTR
# 21   0.000000  55.0      CTR
# 22   0.000000  39.0      CTR
# 23   0.000000  25.0      CTR
# 24   0.000000  49.0      CTR
# 25   0.000000  43.0      CTR
# 26   0.000000  21.0      CTR
# 27   0.000000  44.0      CTR
# 28   0.236842  55.0      PSI
# 29   0.500000  27.0      PSI
# 32   1.388889  33.0      PSI
# 33   3.875000  22.0      PSI
# 35   0.233333  49.0      PSI
# 38   0.321429  52.0      PSI
# 39   0.428571  26.0      PSI
# 40   0.235294  47.0      PSI
# 44   1.714286  35.0      PSI
# 45   0.181818  37.0      PSI
# 47   0.160000  42.0      PSI
# 48   0.769231  30.0      PSI
# 49   1.285714  22.0      PSI
# 53   0.814815  44.0      PSI
# 56   3.357143  46.0      PSI
# 57   0.909091  24.0      PSI
# 60        NaN  28.0      PSI
# 63   0.823529  57.0      PSI
# 64   0.142857  43.0      PSI
# 65   0.791667  46.0      PSI
# 66   0.642857  56.0      PSI
# 67   0.323529  45.0      PSI
# 68   0.600000  32.0      PSI
# 69   0.714286  43.0      PSI
# 71   0.100000  53.0      PSI
# 75   1.550000  53.0      PSI
# 76   0.600000  29.0      PSI
# 77   1.857143  32.0      PSI
# 79   1.478261  39.0      PSI
# 81   4.500000  29.0      PSI
# 82   4.333333  42.0      PSI
# 88   0.500000  53.0      PSI
# 89   1.555556  30.0      PSI
# 92   0.769231  57.0      PSI
# 94   2.000000  21.0      PSI
# 95        NaN   NaN      PSI
# 97   0.153846  51.0      PSI
# 98   2.125000  34.0      PSI
# 100  0.176471  58.0      PSI
# 101  0.714286  46.0      PSI
# 104  2.384615  27.0      PSI
# 105  0.333333  24.0      PSI
# 106  0.172414  52.0      PSI
# 108  1.571429  42.0      PSI
# 109  0.550000  42.0      PSI
# 110  0.206897  50.0      PSI
# 117  1.200000  33.0      PSI
# 122  1.500000  20.0      PSI
# 123  2.000000  27.0      PSI
# 126  0.200000  50.0      PSI
# 127  0.135135  56.0      PSI
# 130  0.625000  54.0      PSI
# 131  0.533333  40.0      PSI
# 132  0.031250  52.0      PSI
# 133       NaN   NaN      PSI
# 134  0.230769  23.0      PSI
# 135  1.000000  52.0      PSI
# 136  0.333333  43.0      PSI
# 139  0.666667  53.0      PSI
# 140  0.571429  24.0      PSI
# 144  1.750000  32.0      PSI
# 145  0.800000  26.0      PSI
# 149  0.391304  37.0      PSI
# 152  0.228571  50.0      PSI
# 153  0.388889  55.0      PSI
# 154  0.285714  52.0      PSI
# 155  0.400000  35.0      PSI
# 158  0.227273  27.0      PSI
# 159  1.173913  44.0      PSI
# 163  1.857143  28.0      PSI
# 164  0.400000  54.0      PSI
# 166  0.142857  55.0      PSI
# 167  1.200000  58.0      PSI
# 169  1.379310  57.0      PSI
# 170  3.500000  28.0      PSI
# 171  0.200000  48.0      PSI
# 172  0.837838  50.0      PSI
# 173  0.571429  34.0      PSI
# 174  0.375000  64.0      PSI
# 178  0.307692  49.0      PSI
# 179  0.083333  62.0      PSI
# 180  0.000000  60.0      PSI
# 181  0.074074  60.0      PSI
# 182  0.000000  35.0      PSI
# 184  0.620690  45.0      PSI
# 187  0.000000  61.0      PSI
# 188  1.100000  33.0      PSI
# 189  0.166667  39.0      PSI
# 190  0.285714  28.0      PSI
# 192  0.200000  59.0      PSI
# 193       NaN   NaN      PSI
# 198  0.142857  42.0      PSI
# 199  0.000000  48.0      PSI
# 200  0.100000  37.0      PSI
# 202       NaN   NaN      PSI
# 204  0.200000  53.0      PSI
# 205  0.000000  30.0      PSI
# 207  0.000000  29.0      PSI
# 208  0.000000  51.0      PSI
# 209  0.000000  58.0      PSI
# 210       NaN   NaN      PSI
# 211  0.000000  46.0      PSI
# 212  0.025641  59.0      PSI
# 213  0.133333  44.0      PSI
# 215  0.500000  38.0      PSI
# 216       NaN   NaN      PSI
# 218  0.173913  39.0      PSI
# 220       NaN   NaN      PSI
# 221       NaN   NaN      PSI
# 222  0.060606  55.0      PSI
# 223       NaN   NaN      PSI
# 224       NaN   NaN      PSI
# 225  0.137931  50.0      PSI
# 226       NaN   NaN      PSI
# 227  0.047619  54.0      PSI
# 229  0.000000  63.0      PSI
# 232  0.250000  27.0      PSI
# 234  0.266667  36.0      PSI
# 237  0.687500  50.0      PSI
# 240       NaN   NaN      PSI
# 243  0.100000  58.0      PSI
# 244  0.000000  40.0      PSI
# 246  0.461538  52.0      PSI
# 247  0.000000  54.0      PSI
# 251  0.000000  52.0      PSI
# 253  0.076923  48.0      PSI
# 254  0.000000  56.0      PSI
# 257  0.064516  56.0      PSI
# 258  0.023256  62.0      PSI
# 259  0.000000  56.0      PSI
# 30   0.125000  50.0      PSI
# 31   0.000000  24.0      PSI
# 34   0.083333  30.0      PSI
# 36   0.055556  33.0      PSI
# 37   0.500000  19.0      PSI
# 42   0.041667  37.0      PSI
# 43   0.250000  48.0      PSI
# 46   0.093750  52.0      PSI
# 51   0.062500  48.0      PSI
# 52        NaN   NaN      PSI
# 55   0.400000  20.0      PSI
# 58   0.227273  45.0      PSI
# 59   0.235294  25.0      PSI
# 61   0.166667  37.0      PSI
# 62   0.076923  32.0      PSI
# 70   0.062500  44.0      PSI
# 73   0.166667  40.0      PSI
# 74   0.208333  44.0      PSI
# 80   0.857143  21.0      PSI
# 83   0.333333  31.0      PSI
# 84   0.076923  52.0      PSI
# 85   0.035714  56.0      PSI
# 86   0.000000  21.0      PSI
# 87   0.000000  30.0      PSI
# 90   0.000000  46.0      PSI
# 91   0.714286  27.0      PSI
# 93   1.000000  30.0      PSI
# 96   0.571429  25.0      PSI
# 99   0.115385  59.0      PSI
# 102  0.454545  28.0      PSI
# 103  0.137931  47.0      PSI
# 112  1.000000  24.0      PSI
# 113  1.500000  23.0      PSI
# 115  4.000000  21.0      PSI
# 116  0.150000  52.0      PSI
# 120  0.000000  33.0      PSI
# 121  2.142857  24.0      PSI
# 124  1.363636  45.0      PSI
# 125  0.090909  37.0      PSI
# 128  2.000000  19.0      PSI
# 129  0.142857  23.0      PSI
# 137  0.000000  44.0      PSI
# 138  0.750000  18.0      PSI
# 141  0.600000  41.0      PSI
# 142  0.166667  42.0      PSI
# 143  0.064516  48.0      PSI
# 146  1.117647  35.0      PSI
# 147  0.000000  20.0      PSI
# 148  0.058824  34.0      PSI
# 150  0.000000  23.0      PSI
# 151  0.571429  34.0      PSI
# 156       NaN   NaN      PSI
# 157       NaN   NaN      PSI
# 160  0.000000  44.0      PSI
# 161  1.000000  23.0      PSI
# 162       NaN  23.0      PSI
# 165  0.363636  29.0      PSI
# 168  0.060606  57.0      PSI
# 175  0.000000  38.0      PSI
# 176  0.000000  52.0      PSI
# 177  0.000000  51.0      PSI
# 183  0.000000  62.0      PSI
# 185  0.000000  37.0      PSI
# 186  0.000000  59.0      PSI
# 191  0.000000  43.0      PSI
# 194       NaN   NaN      PSI
# 195  0.000000  27.0      PSI
# 196  0.000000  42.0      PSI
# 197  0.000000  58.0      PSI
# 201  0.000000  55.0      PSI
# 203  0.000000  54.0      PSI
# 206       NaN   NaN      PSI
# 214  0.000000  41.0      PSI
# 217  0.000000  41.0      PSI
# 219  0.750000  21.0      PSI
# 228  0.000000  35.0      PSI
# 230  0.000000  64.0      PSI
# 231  0.000000  29.0      PSI
# 233       NaN   NaN      PSI
# 235  0.000000  28.0      PSI
# 236  0.000000  37.0      PSI
# 238       NaN   NaN      PSI
# 239  0.000000  33.0      PSI
# 241  0.058824  34.0      PSI
# 242  0.000000  66.0      PSI
# 245  0.000000  54.0      PSI
# 249       NaN   NaN      PSI
# 250       NaN   NaN      PSI
# 252       NaN   NaN      PSI
# 256  0.000000  43.0      PSI
# 260  0.000000  40.0      PSI
#
# [249 rows x 460 columns]

# %%
all_data_sorted_EQF = clinical_image_EQF.sort_values('c_group', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

count_groups_EQF = all_data_sorted_EQF.groupby(['c_group']).count()
groups_dict_EQF = count_groups_EQF['subject'].to_dict()

list_len_EQF = list(groups_dict_EQF.values())
groups_EQF = list(groups_dict_EQF.keys())
groups_dict_EQF
# Out:
# {'CTR-controles': 28, 'EQZ-prisma1': 55, 'EQZ-prisma3': 33}

# %%
all_data_sorted_EQF = all_data_sorted_EQF.dropna(subset=['c_group'])
#all_data_sorted_EQF

# %%
count_groups_EQF = all_data_sorted_EQF.groupby(['c_group']).count()
groups_dict_EQF = count_groups_EQF['subject'].to_dict()

list_len_EQF = list(groups_dict_EQF.values())
groups_EQF = list(groups_dict_EQF.keys())
groups_dict_EQF
# Out:
# {'CTR-controles': 28, 'EQZ-prisma1': 55, 'EQZ-prisma3': 33}

# %%
all_data_sorted_TAB = clinical_image_TAB.sort_values('c_group', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

count_groups_TAB = all_data_sorted_TAB.groupby(['c_group']).count()
groups_dict_TAB = count_groups_TAB['subject'].to_dict()

list_len_TAB = list(groups_dict_TAB.values())
groups_TAB = list(groups_dict_TAB.keys())
groups_dict_TAB
# Out:
# {'CTR-controles': 28, 'TAB-prisma1': 75, 'TAB-prisma3': 53}

# %%
all_data_sorted_TAB = all_data_sorted_TAB.dropna(subset=['c_group'])
#all_data_sorted_TAB

# %%
count_groups_TAB = all_data_sorted_TAB.groupby(['c_group']).count()
groups_dict_TAB = count_groups_TAB['subject'].to_dict()

list_len_TAB = list(groups_dict_TAB.values())
groups_TAB = list(groups_dict_TAB.keys())
groups_dict_TAB
# Out:
# {'CTR-controles': 28, 'TAB-prisma1': 75, 'TAB-prisma3': 53}

# %%
all_data_sorted_PSI = clinical_image_i.sort_values('c_group', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

count_groups_PSI = all_data_sorted_PSI.groupby(['c_group']).count()
groups_dict_PSI = count_groups_PSI['subject'].to_dict()

list_len_PSI = list(groups_dict_PSI.values())
groups_PSI = list(groups_dict_PSI.keys())
groups_dict_PSI
# Out:
# {'CTR-controles-CTR': 28,
#  'PSI-prisma1-EQF': 58,
#  'PSI-prisma1-TAB': 77,
#  'PSI-prisma3-EQF': 33,
#  'PSI-prisma3-TAB': 53}

# %%
all_data_sorted_PSI = all_data_sorted_PSI.dropna(subset=['c_group'])
count_groups_PSI= all_data_sorted_PSI.groupby(['c_group']).count()
groups_dict_PSI = count_groups_PSI['subject'].to_dict()

list_len_PSI = list(groups_dict_PSI.values())
groups_PSI = list(groups_dict_PSI.keys())
groups_dict_PSI
# Out:
# {'CTR-controles-CTR': 28,
#  'PSI-prisma1-EQF': 58,
#  'PSI-prisma1-TAB': 77,
#  'PSI-prisma3-EQF': 33,
#  'PSI-prisma3-TAB': 53}

# %% [markdown]
# ## PLS WITH CLINICAL GROUPS

# %%
X_EQF = all_data_sorted_EQF.iloc[:,4:-6].values
X_TAB = all_data_sorted_TAB.iloc[:,4:-6].values
X_PSI = all_data_sorted_PSI.iloc[:,4:-7].values

# %%
random_state=42
pls_EQF = pyls.meancentered_pls(X_EQF, groups=list_len_EQF, seed=42, mean_centering=1, n_proc='max')
# Out:
# Running permutations:   0%|                                                            | 0/5000 | 00:00<?/opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# Running permutations:   0%|1                                                      | 16/5000 | 00:00<05:06nt your code to be deterministic or not.m_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you wa
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(
# /opt/miniconda3/lib/python3.9/site-packages/scikit_learn-1.1.1-py3.9-macosx-11.1-arm64.egg/sklearn/utils/extmath.py:369: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(

# %%
#with open('pls_V_EQF_n.pkl', 'wb') as f:
with open('pls_EQF.pkl', 'wb') as f:
    pickle.dump(pls_EQF, f)

# %%
with open("pls_EQF.pkl", "rb") as input_file:
    pls_EQF = pickle.load(input_file)

# %%
pls_TAB = pyls.meancentered_pls(X_TAB, groups=list_len_TAB, mean_centering=1, seed=42, n_proc='max')

# %%
with open('pls_TAB.pkl', 'wb') as f:
    pickle.dump(pls_TAB, f)

# %%
with open("pls_TAB.pkl", "rb") as input_file:
    pls_TAB = pickle.load(input_file)

# %%
pls_PSI = pyls.meancentered_pls(X_PSI, groups=list_len_PSI, seed=42, mean_centering=1, n_proc='max')

# %%
# Significancia PLS grupos EQF y CTRL, tiempo y tratamiento
pvals_EQF = pls_EQF.permres['pvals']
x_weights_EQF = pls_EQF.bootres.x_weights_normed 
y_weights_EQF = pls_EQF.y_weights
pvals_EQF
# Out:
# array([1., 1., 1.])

# %%
# Significancia grupos TAB y CTRL, tiempo y tratamiento
pvals_TAB = pls_TAB.permres['pvals']
x_weights_TAB = pls_TAB.bootres.x_weights_normed
y_weights_TAB = pls_TAB.y_weights
pvals_TAB
# Out:
# array([1., 1., 1.])

# %%
# Significancia grupos EQF+TAB y CTRL, tiempo y tratamiento
pvals_PSI = pls_PSI.permres['pvals']
x_weights_PSI = pls_PSI.bootres.x_weights_normed
y_weights_PSI = pls_PSI.y_weights
pvals_PSI
# Out:
# array([0.99820036, 1.        , 1.        , 1.        , 1.        ])

# %%
def get_pos(n_col, init=-0.3, inte=0.6):
    pos = []
    for i in range(n_col):
        x = init 
        init = round(x + inte, 1)
        pos.append(x)
    return pos

def errplot(x,y, yerr, **kwargs):
    data = kwargs.pop("data")
    plt.errorbar(x=x,y=data[y],yerr=data[yerr],fmt='none', c= 'k')

# %%
# Incluyendo tratamiento
#y_loadings_df_EQF = pd.DataFrame({'1': y_weights_EQF[:,0], '2': y_weights_EQF[:,1], 'condition': groups_EQF,
#                                  'tratamiento': [group.split("-")[2] for group in groups_EQF] , 'time': [group.split("-")[1] for group in groups_EQF]})

#y_loadings_m_EQF = pd.melt(y_loadings_df_EQF,id_vars=['condition','tratamiento','time'],value_name='weight', var_name = 'salvar_id')

# Sin tratamiento
y_loadings_df_EQF = pd.DataFrame({'1': y_weights_EQF[:,0], '2': y_weights_EQF[:,1], 'condition': groups_EQF,
                                  'time': [group.split("-")[1] for group in groups_EQF]})

y_loadings_m_EQF = pd.melt(y_loadings_df_EQF,id_vars=['condition','time'],value_name='weight', var_name = 'salvar_id')

y_loadings_m_EQF['ci_l'] = np.concatenate([pls_EQF.bootres.contrast_ci[:,0,0], pls_EQF.bootres.contrast_ci[:,1,0]])
y_loadings_m_EQF['ci_u'] = np.concatenate([pls_EQF.bootres.contrast_ci[:,0,1], pls_EQF.bootres.contrast_ci[:,1,1]])

y_loadings_m_EQF['ci_l_p'] = y_loadings_m_EQF['weight'] - y_loadings_m_EQF['ci_l']
y_loadings_m_EQF['ci_u_p'] = y_loadings_m_EQF['weight'] - y_loadings_m_EQF['ci_u']
y_loadings_m_EQF['err'] = (y_loadings_m_EQF['ci_u'] - y_loadings_m_EQF['ci_l'])/2

# %%
y_loadings_m_EQF
# Out:
#        condition       time salvar_id    weight      ci_l      ci_u    ci_l_p  \
# 0  CTR-controles  controles         1 -0.134290 -1.427300  0.846267  1.293009
# 1    EQZ-prisma1    prisma1         1 -0.630332 -2.564489 -0.528703  1.934157
# 2    EQZ-prisma3    prisma3         1  0.764622  0.789505  2.891042 -0.024882
# 3  CTR-controles  controles         2  0.805377 -0.751628  1.276713  1.557005
# 4    EQZ-prisma1    prisma1         2 -0.518988 -0.953437  0.643054  0.434449
# 5    EQZ-prisma3    prisma3         2 -0.286390 -1.027732  0.876229  0.741342
#
#      ci_u_p       err
# 0 -0.980557  1.136783
# 1 -0.101629  1.017893
# 2 -2.126420  1.050769
# 3 -0.471336  1.014171
# 4 -1.162042  0.798245
# 5 -1.162619  0.951980

# %%
#y_loadings_df_TAB = pd.DataFrame({'1': y_weights_TAB[:,0], '2': y_weights_TAB[:,1], 'condition': groups_TAB,
#                                 'tratamiento': [group.split("-")[2] for group in groups_TAB] , 'time': [group.split("-")[1] for group in groups_TAB]})
#y_loadings_m_TAB = pd.melt(y_loadings_df_TAB,id_vars=['condition','tratamiento','time'],value_name='weight', var_name = 'salvar_id')

y_loadings_df_TAB = pd.DataFrame({'1': y_weights_TAB[:,0], '2': y_weights_TAB[:,1], 'condition': groups_TAB,
                                  'time': [group.split("-")[1] for group in groups_TAB]})
y_loadings_m_TAB = pd.melt(y_loadings_df_TAB,id_vars=['condition','time'],value_name='weight', var_name = 'salvar_id')

y_loadings_m_TAB['ci_l'] = np.concatenate([pls_TAB.bootres.contrast_ci[:,0,0], pls_TAB.bootres.contrast_ci[:,1,0]])
y_loadings_m_TAB['ci_u'] = np.concatenate([pls_TAB.bootres.contrast_ci[:,0,1], pls_TAB.bootres.contrast_ci[:,1,1]])

y_loadings_m_TAB['ci_l_p'] = y_loadings_m_TAB['weight'] - y_loadings_m_TAB['ci_l']
y_loadings_m_TAB['ci_u_p'] = y_loadings_m_TAB['weight'] - y_loadings_m_TAB['ci_u']
y_loadings_m_TAB['err'] = (y_loadings_m_TAB['ci_u'] - y_loadings_m_TAB['ci_l'])/2

# %%
y_loadings_df_PSI = pd.DataFrame({'1': y_weights_PSI[:,0], '2': y_weights_PSI[:,1], 'condition': groups_PSI,
                                  'enfermedad': [group.split("-")[2] for group in groups_PSI] , 'time': [group.split("-")[1] for group in groups_PSI]})

y_loadings_m_PSI = pd.melt(y_loadings_df_PSI,id_vars=['condition','enfermedad','time'],value_name='weight', var_name = 'salvar_id')

#y_loadings_df_PSI = pd.DataFrame({'1': y_weights_PSI[:,0], '2': y_weights_PSI[:,1], 'condition': groups_PSI,
#                                  'time': [group.split("-")[1] for group in groups_PSI]})

#y_loadings_m_PSI = pd.melt(y_loadings_df_PSI,id_vars=['condition','time'],value_name='weight', var_name = 'salvar_id')

y_loadings_m_PSI['ci_l'] = np.concatenate([pls_PSI.bootres.contrast_ci[:,0,0], pls_PSI.bootres.contrast_ci[:,1,0]])
y_loadings_m_PSI['ci_u'] = np.concatenate([pls_PSI.bootres.contrast_ci[:,0,1], pls_PSI.bootres.contrast_ci[:,1,1]])

y_loadings_m_PSI['ci_l_p'] = y_loadings_m_PSI['weight'] - y_loadings_m_PSI['ci_l']
y_loadings_m_PSI['ci_u_p'] = y_loadings_m_PSI['weight'] - y_loadings_m_PSI['ci_u']
y_loadings_m_PSI['err'] = (y_loadings_m_PSI['ci_u'] - y_loadings_m_PSI['ci_l'])/2

# %%
y_loadings_m_PSI
# Out:
#            condition enfermedad       time salvar_id    weight      ci_l  \
# 0  CTR-controles-CTR        CTR  controles         1 -0.089581 -1.485104
# 1    PSI-prisma1-EQF        EQF    prisma1         1 -0.564529 -2.465131
# 2    PSI-prisma1-TAB        TAB    prisma1         1 -0.284120 -1.645371
# 3    PSI-prisma3-EQF        EQF    prisma3         1  0.745177  0.737964
# 4    PSI-prisma3-TAB        TAB    prisma3         1  0.193052 -0.587993
# 5  CTR-controles-CTR        CTR  controles         2 -0.024111 -0.994405
# 6    PSI-prisma1-EQF        EQF    prisma1         2  0.137563 -0.465061
# 7    PSI-prisma1-TAB        TAB    prisma1         2 -0.560808 -1.647269
# 8    PSI-prisma3-EQF        EQF    prisma3         2 -0.308265 -1.352548
# 9    PSI-prisma3-TAB        TAB    prisma3         2  0.755620  0.636676
#
#        ci_u    ci_l_p    ci_u_p       err
# 0  1.060952  1.395524 -1.150533  1.273028
# 1 -0.463666  1.900602 -0.100863  1.000732
# 2  0.156700  1.361251 -0.440819  0.901035
# 3  3.046660  0.007213 -2.301483  1.154348
# 4  1.534536  0.781045 -1.341484  1.061265
# 5  0.911423  0.970295 -0.935533  0.952914
# 6  0.965806  0.602625 -0.828242  0.715434
# 7 -0.329558  1.086461 -0.231250  0.658855
# 8  0.251125  1.044283 -0.559390  0.801836
# 9  2.080726  0.118944 -1.325106  0.722025

# %%
#g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2, hue="tratamiento",data=y_loadings_m_TAB)

g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2, data=y_loadings_m_TAB)

#g.map_dataframe(errplot,  [-0.26,1,1.26,2,2.26], "weight", "err")
g.map_dataframe(errplot,  [0,1,2], "weight", "err")
plt.suptitle('PLS Mean centered TAB')
g.set_xlabels('')

# %%
#g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2, hue="tratamiento",data=y_loadings_m_EQF)
#g.map_dataframe(errplot, [-0.26,1,1.26,2,2.26], "weight", "err")

g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2,data=y_loadings_m_EQF)
g.map_dataframe(errplot, [0,1,2], "weight", "err")

plt.suptitle('PLS Mean centered EQF')
g.set_xlabels('')

# %%
g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2, hue="enfermedad",data=y_loadings_m_PSI)
g.map_dataframe(errplot, [-0.26,1,1.26,2,2.26], "weight", "err")

#g = sns.catplot(x="time", y="weight", kind="bar", col="salvar_id", ci=None, aspect=1.2,data=y_loadings_m_PSI)
#g.map_dataframe(errplot, [0,1,2], "weight", "err")

plt.suptitle('PLS Mean centered EQF+TAB')
g.set_xlabels('')

# %%
pls_EQF.permres.pvals
# Out:
# array([1., 1., 1.])

# %%
pls_EQF.varexp
# Out:
# array([9.83010142e-01, 1.69898579e-02, 1.96883180e-34])

# %%
pls_TAB.permres.pvals
# Out:
# array([1., 1., 1.])

# %%
pls_TAB.varexp
# Out:
# array([9.91674803e-01, 8.32519673e-03, 3.45513768e-36])

# %%
pls_PSI.permres.pvals
# Out:
# array([0.99820036, 1.        , 1.        , 1.        , 1.        ])

# %%
pls_PSI.varexp
# Out:
# array([6.78183880e-01, 3.21816120e-01, 4.28827387e-29, 2.51607080e-29,
#        1.07548015e-34])

# %%
print(pls_PSI.bootres.x_weights_normed.min(), pls_PSI.bootres.x_weights_normed.max())
# Out:
# -2.6182068791461126 2.4322220496048725

# %% [markdown]
# Gráficos de dispersión

# %%
score_EQF = pd.DataFrame()
score_EQF['subject'] = all_data_sorted_EQF['subject']
score_EQF['grupo'] = all_data_sorted_EQF['grupo']
score_EQF['subject'] = all_data_sorted_EQF['subject']
score_EQF['project'] = all_data_sorted_EQF['project']
score_EQF['treatment'] = all_data_sorted_EQF['treatment']
score_EQF['psc'] = all_data_sorted_EQF['psc'].where(pd.notnull(all_data_sorted_EQF['psc']), -1).astype(int)
score_EQF['Gravedad'] = all_data_sorted_EQF['Gravedad']
score_EQF['x_score_1']=pls_EQF.x_scores[:,0]
score_EQF['y_score_1']=pls_EQF.y_scores[:,0]
score_EQF['x_score_2']=pls_EQF.x_scores[:,1]
score_EQF['y_score_2']=pls_EQF.y_scores[:,1]

score_TAB = pd.DataFrame()
score_TAB['subject'] = all_data_sorted_TAB['subject']
score_TAB['grupo'] = all_data_sorted_TAB['grupo']
score_TAB['subject'] = all_data_sorted_TAB['subject']
score_TAB['project'] = all_data_sorted_TAB['project']
score_TAB['treatment'] = all_data_sorted_TAB['treatment']
score_TAB['psc'] = all_data_sorted_TAB['psc'].where(pd.notnull(all_data_sorted_TAB['psc']), -1).astype(int)
score_TAB['Gravedad'] = all_data_sorted_TAB['Gravedad']
score_TAB['x_score_1']=pls_TAB.x_scores[:,0]
score_TAB['y_score_1']=pls_TAB.y_scores[:,0]
score_TAB['x_score_2']=pls_TAB.x_scores[:,1]
score_TAB['y_score_2']=pls_TAB.y_scores[:,1]

# %%
score_PSI = pd.DataFrame()
score_PSI['subject'] = all_data_sorted_PSI['subject']
score_PSI['grupo'] = all_data_sorted_PSI['grupo']
score_PSI['grupo-p'] = all_data_sorted_PSI['grupo-p']
score_PSI['edad'] = all_data_sorted_PSI['edad']
score_PSI['project'] = all_data_sorted_PSI['project']
score_PSI['treatment'] = all_data_sorted_PSI['treatment']
score_PSI['psc'] = all_data_sorted_PSI['psc'].where(pd.notnull(all_data_sorted_PSI['psc']), -1).astype(int)
score_PSI['Gravedad'] = all_data_sorted_PSI['Gravedad']
score_PSI['x_score_1']=pls_PSI.x_scores[:,0]
score_PSI['y_score_1']=pls_PSI.y_scores[:,0]
score_PSI['x_score_2']=pls_PSI.x_scores[:,1]
score_PSI['y_score_2']=pls_PSI.y_scores[:,1]

# %%
score_PSI

# %%
#color = {0: 'w', 1: 'k', 100: 'r'}
color = {0: 'w', 1: 'k', -1: 'r'}
#color = {'controles':'w','prisma1': 'w','prisma3':'k'}
le = LabelEncoder()
subject_n = pd.factorize(score_TAB.apply(lambda x: 'CTRL' if 'CTRL' in x['subject'] else x['subject'], axis=1))[0]
score_TAB['subject_color'] = le.fit_transform(subject_n)
score_TAB['edge_color'] = score_TAB.apply(lambda x: color[x['psc']], axis=1)
#score_TAB['line_width'] = score_TAB.apply(lambda x: line[x['psc']], axis=1)

lee = LabelEncoder()
subject_n = pd.factorize(score_EQF.apply(lambda x: 'CTRL' if 'CTRL' in x['subject'] else x['subject'], axis=1))[0]
score_EQF['subject_color'] = lee.fit_transform(subject_n)
score_EQF['edge_color'] = score_EQF.apply(lambda x: color[x['psc']], axis=1)
#score_TAB['line_width'] = score_TAB.apply(lambda x: line[x['psc']], axis=1)

# %%
color = {0: 'w', 1: 'k', -1: 'r'}
lep = LabelEncoder()
subject_n = pd.factorize(score_PSI.apply(lambda x: 'CTRL' if 'CTRL' in x['subject'] else x['subject'], axis=1))[0]
score_PSI['subject_color'] = lep.fit_transform(subject_n)
score_PSI['edge_color'] = score_PSI.apply(lambda x: color[x['psc']], axis=1)
#score_TAB['line_width'] = score_TAB.apply(lambda x: line[x['psc']], axis=1)

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="y_score_1",
                  hue="subject_color", style="project", size='treatment',sizes=[16,64,236],
                  palette='tab20',data=score_EQF,edgecolor=score_EQF["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[60:]
selected_labels = current_labels[60:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE VS Y SCORE LV 1 EQF")
plt.show()

# %%
# Gráfico variable latente 1 vs variable latente 2
sns.set(rc={'figure.figsize':(11,8)})
        
g=sns.scatterplot(x="x_score_1", y="x_score_2",
                  hue="subject_color", style="project", size='treatment',sizes=[16,128,236],legend=True,
                  palette='tab20',data=score_EQF,edgecolor=score_EQF["edge_color"],linewidth=1)


current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[60:]
selected_labels = current_labels[60:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS X SCORE LV2 EQF")
plt.show()

# %%
# Gráfico variable latente 1 vs gravedad
score_EQF_na = score_EQF.dropna(subset=['Gravedad'])
g=sns.scatterplot(x="x_score_1", y="Gravedad",
                 hue="subject_color", style="project", size='treatment',sizes=[16,128,236],
                palette='tab20',data=score_EQF_na,edgecolor=score_EQF_na["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[59:]
selected_labels = current_labels[59:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS Gravedad EQF")
plt.show()

# %%
g=sns.scatterplot(x="x_score_1", y="y_score_1",
                 hue="subject_color", style="project", size='treatment',sizes=[16,64,236],
                palette='tab20',data=score_TAB,edgecolor=score_TAB["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[84:]
selected_labels = current_labels[84:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE VS Y SCORE LV 1 TAB")
plt.show()

# %%
#sns.set(rc={'figure.figsize':(11,8)})
g= sns.scatterplot(x="x_score_1", y="x_score_2",
                hue="subject_color", style="project", size='treatment',sizes=[16,128,236],legend=True,
                palette='tab20',data=score_TAB,edgecolor=score_TAB["edge_color"],linewidth=1)

current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[84:]
selected_labels = current_labels[84:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS X SCORE LV2 TAB")
plt.show()

# %%
score_TAB_na = score_TAB.dropna(subset=['Gravedad'])
markers = {0.0: "X", 1.0: "o",2.0:"s"}
g=sns.scatterplot(x="x_score_1", y="Gravedad",
                  hue="subject_color", style="project", size='treatment',sizes=[16,128,236],
                  palette='tab20',data=score_TAB,edgecolor=score_TAB["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[84:]
selected_labels = current_labels[84:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS Gravedad TAB")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="y_score_1",
                  hue="subject_color", style="project", size='treatment',sizes=[16,64,236],
                  palette='tab20',data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[146:]
selected_labels = current_labels[146:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE VS Y SCORE LV 1 EQF+TAB")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="y_score_1",
                  hue="grupo", style="project", size='treatment',sizes=[16,64,236],
                  palette='tab20',data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)
#current_handles, current_labels = g.get_legend_handles_labels()
#selected_handles = current_handles[146:]
#selected_labels = current_labels[146:]
#plt.legend(selected_handles,selected_labels)
plt.title("X SCORE VS Y SCORE LV 1 EQF+TAB")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="x_score_2",
                 hue="subject_color", style="project", size='treatment',sizes=[16,128,236],legend=True,
                palette='tab20',data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[146:]
selected_labels = current_labels[146:]
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS X SCORE LV2 EQF+TAB")
plt.show()

# %%
sizes = {'CTR': 128, 'EQF':236 ,'TAB':236}
score_PSI['grupo-size'] = score_PSI.apply(lambda x: sizes[x['grupo']], axis=1)
#score_TAB['line_width'] = score_TAB.apply(lambda x: line[x['psc']], axis=1)
score_PSI

# %%
g=sns.scatterplot(x="x_score_1", y="x_score_2", size=score_PSI['grupo-size'],
                  hue="grupo", style="project",legend=True,
                  data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)

current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[0:4]
selected_handles.extend(current_handles[7:11])
selected_labels = current_labels[0:4]
selected_labels.extend(current_labels[7:11])
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS X SCORE LV2 EQF+TAB")
plt.show()

# %%
score_PSI_na = score_PSI.dropna(subset=['Gravedad'])
#g=sns.scatterplot(x="x_score_1", y="Gravedad",
#                 hue="subject_color", style="project", size='treatment',sizes=[16,128,236],
#                palette='tab20',data=score_PSI_na,edgecolor=score_PSI_na["edge_color"],linewidth=1)
g=sns.scatterplot(x="x_score_1", y="Gravedad", size=score_PSI['grupo-size'],
                  hue="grupo", style="project",legend=True,
                  data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[0:4]
selected_handles.extend(current_handles[7:11])
selected_labels = current_labels[0:4]
selected_labels.extend(current_labels[7:11])
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS Gravedad EQF+TAB")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="psc", size=score_PSI['grupo-size'],
                  hue="grupo", style="project",legend=True,
                  data=score_PSI,linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[0:4]
selected_handles.extend(current_handles[7:11])
selected_labels = current_labels[0:4]
selected_labels.extend(current_labels[7:11])
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS Psicosis EQF+TAB")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8)})
g=sns.scatterplot(x="x_score_1", y="edad", size=score_PSI['grupo-size'],
                  hue="grupo", style="project",legend=True,
                  data=score_PSI,edgecolor=score_PSI["edge_color"],linewidth=1)
current_handles, current_labels = g.get_legend_handles_labels()
selected_handles = current_handles[0:4]
selected_handles.extend(current_handles[7:11])
selected_labels = current_labels[0:4]
selected_labels.extend(current_labels[7:11])
plt.legend(selected_handles,selected_labels)
plt.title("X SCORE LV1 VS Edad EQF+TAB")
plt.show()

# %% [markdown]
# ## X Weights

# %%
yeo_pal = {'Vis': (0.47058823529411764, 0.07058823529411765, 0.5254901960784314),
 'SomMot': (0.27450980392156865, 0.5098039215686274, 0.7058823529411765),
 'DorsAttn': (0.0, 0.4627450980392157, 0.054901960784313725),
 'SalVentAttn': (0.7686274509803922, 0.22745098039215686, 0.9803921568627451),
 'Limbic': (0.8627450980392157, 0.9725490196078431, 0.6431372549019608),
 'Cont': (0.9019607843137255, 0.5803921568627451, 0.13333333333333333),
 'Default': (0.803921568627451, 0.24313725490196078, 0.3058823529411765),
 'None': (0.7, 0.7, 0.7, 0.5),
 'TempPar': 'blue'}

# %%
EQF_data = all_data_sorted_EQF.iloc[:,4:-5] # Selecciona sólo los datos de volúmenes 
networks7_order = pd.read_csv('Schaefer2018_400Parcels_17Networks_order.txt',header=None,delimiter=' ')

sch_x_sch_weights_EQF = pls_EQF.bootres.x_weights_normed[49:,0] # Selección variables corticales
df_x_weights_sch_EQF = pd.DataFrame(sch_x_sch_weights_EQF, columns=["weight"])
df_x_weights_sch_EQF.index = networks7_order[1]
df_x_weights_sch_EQF["network"] = df_x_weights_sch_EQF.index.str.split('_').str.get(2)

df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('Vis'), 'network'] = 'Vis'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('SomMot'), 'network'] = 'SomMot'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('DorsAttn'), 'network'] = 'DorsAttn'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('SalVentAttn'), 'network'] = 'SalVentAttn'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('Limbic'), 'network'] = 'Limbic'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('Cont'), 'network'] = 'Cont'
df_x_weights_sch_EQF.loc[df_x_weights_sch_EQF.network.str.contains('Default'), 'network'] = 'Default'

th = 3 
df_x_weights_sch_EQF["weight_th"] =  (abs(df_x_weights_sch_EQF["weight"])>= th)*1


fig, axes = plt.subplots(1, 2, sharex=False, figsize=(15,5))
fig.suptitle('X weights cortical volumes EQF')

order_g = df_x_weights_sch_EQF.groupby(["network"]).mean().sort_values(by='weight').index
g = sns.barplot(x="network", y="weight", ax=axes[0], palette=yeo_pal,
                order=order_g, data=df_x_weights_sch_EQF)

g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
order_h = df_x_weights_sch_EQF.groupby(["network"]).sum().sort_values(by='weight_th').index
h = sns.barplot(x="network", y="weight_th", ci=None, ax=axes[1], estimator=sum, palette=yeo_pal,
                order=order_h, data=df_x_weights_sch_EQF)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)

# %%
sch_x_v_weights_EQF = pls_EQF.bootres.x_weights_normed[:49,0]
df_x_weights_v_EQF = pd.DataFrame(sch_x_v_weights_EQF, columns=["weight"])
df_x_weights_v_EQF['volume'] = list(EQF_data.iloc[:,:49].columns)
#df_x_weights_v_EQF['category'] = ['Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','3rd-Ventricle','4th-Ventricle','Brain-Stem','Hippocampus','Amygdala','CSF','Accumbens-area','VentralDC','vessel','choroid-plexus','Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','Hippocampus','Amygdala','Accumbens-area','VentralDC','vessel','choroid-plexus','Optic-Chiasm','CC','CC','CC','CC','CC']
th = 3
df_x_weights_v_EQF["weight_th"] =  (abs(df_x_weights_v_EQF["weight"])>= th)*1

fig, axes = plt.subplots(1, 2, sharex=True, figsize=(15,5))
fig.suptitle('X weights subcortical volumes EQF')

#g=sns.barplot(x="category", y="weight", ci=None, ax=axes[0],
#            data=df_x_weights_v_EQF)
g=sns.barplot(x="volume", y="weight", ci=None, ax=axes[0],
              data=df_x_weights_v_EQF)
g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
h = sns.barplot(x="volume", y="weight_th", ci=None, ax=axes[1], estimator=sum,
            data=df_x_weights_v_EQF)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)

# %%
schaefer_image = 'Schaefer2018_400_17N_MNI152_2mm.nii'
sch_masker=input_data.NiftiLabelsMasker(schaefer_image)
sch_values=sch_masker.fit()
th = 3
values_brain_weight_vol = sch_masker.inverse_transform(sch_x_sch_weights_EQF[np.newaxis,:])
plotting.view_img(values_brain_weight_vol, threshold=th, title='X weights EQF', symmetric_cmap=False)

# %% [markdown]
# ## TAB

# %%
TAB_data = all_data_sorted_TAB.iloc[:,4:-5]
networks7_order = pd.read_csv('Schaefer2018_400Parcels_17Networks_order.txt',header=None,delimiter='\t')
sch_x_sch_weights_TAB = pls_TAB.bootres.x_weights_normed[49:,0]
df_x_weights_sch_TAB = pd.DataFrame(sch_x_sch_weights_TAB, columns=["weight"])
df_x_weights_sch_TAB.index = networks7_order[1]
df_x_weights_sch_TAB["network"] = df_x_weights_sch_TAB.index.str.split('_').str.get(2)

df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('Vis'), 'network'] = 'Vis'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('SomMot'), 'network'] = 'SomMot'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('DorsAttn'), 'network'] = 'DorsAttn'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('SalVentAttn'), 'network'] = 'SalVentAttn'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('Limbic'), 'network'] = 'Limbic'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('Cont'), 'network'] = 'Cont'
df_x_weights_sch_TAB.loc[df_x_weights_sch_TAB.network.str.contains('Default'), 'network'] = 'Default'

th = 3
df_x_weights_sch_TAB["weight_th"] =  (abs(df_x_weights_sch_TAB["weight"])>= th)*1


fig, axes = plt.subplots(1, 2, sharex=False, figsize=(15,5))
fig.suptitle('X weights cortical volumes TAB')

order_g = df_x_weights_sch_TAB.groupby(["network"]).mean().sort_values(by='weight').index
g = sns.barplot(x="network", y="weight", ax=axes[0], order= order_g,palette=yeo_pal,
            data=df_x_weights_sch_TAB)
g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
order_h = df_x_weights_sch_TAB.groupby(["network"]).sum().sort_values(by='weight_th').index
h = sns.barplot(x="network", y="weight_th", ci=None, ax=axes[1], estimator=sum,order= order_h,palette=yeo_pal,
            data=df_x_weights_sch_TAB)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)

# %%
sch_x_v_weights_TAB = pls_TAB.bootres.x_weights_normed[:49,0]
df_x_weights_v_TAB = pd.DataFrame(sch_x_v_weights_TAB, columns=["weight"])
df_x_weights_v_TAB['volume'] = list(TAB_data.iloc[:,:49].columns)
#df_x_weights_v_TAB['category'] = ['Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','3rd-Ventricle','4th-Ventricle','Brain-Stem','Hippocampus','Amygdala','CSF','Accumbens-area','VentralDC','vessel','choroid-plexus','Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','Hippocampus','Amygdala','Accumbens-area','VentralDC','vessel','choroid-plexus','Optic-Chiasm','CC','CC','CC','CC','CC']
th = 3
df_x_weights_v_TAB["weight_th"] =  (abs(df_x_weights_v_TAB["weight"])>= th)*1

fig, axes = plt.subplots(1, 2, sharex=True, figsize=(15,5))
fig.suptitle('X weights subcortical volumes TAB')

g=sns.barplot(x="volume", y="weight", ci=None, ax=axes[0],
            data=df_x_weights_v_TAB)
g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
h = sns.barplot(x="volume", y="weight_th", ci=None, ax=axes[1], estimator=sum,
            data=df_x_weights_v_TAB)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)

# %%
schaefer_image = 'Schaefer2018_400_17N_MNI152_2mm.nii'
sch_masker=input_data.NiftiLabelsMasker(schaefer_image)
sch_values=sch_masker.fit()
#th = max(sch_x_sch_weights_TAB)*0.6
th=3
values_brain_weight_vol = sch_masker.inverse_transform(sch_x_sch_weights_TAB[np.newaxis,:])
plotting.view_img(values_brain_weight_vol, threshold=th, title='X weights TAB', symmetric_cmap=False)

# %% [markdown]
# EQF+TAB

# %%
PSI_data = all_data_sorted_PSI.iloc[:,4:-6]
networks7_order = pd.read_csv('Schaefer2018_400Parcels_17Networks_order.txt',header=None,delimiter='\t')
sch_x_sch_weights_PSI = pls_PSI.bootres.x_weights_normed[49:,0]
df_x_weights_sch_PSI = pd.DataFrame(sch_x_sch_weights_PSI, columns=["weight"])
df_x_weights_sch_PSI.index = networks7_order[1]
df_x_weights_sch_PSI["network"] = df_x_weights_sch_PSI.index.str.split('_').str.get(2)

df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('Vis'), 'network'] = 'Vis'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('SomMot'), 'network'] = 'SomMot'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('DorsAttn'), 'network'] = 'DorsAttn'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('SalVentAttn'), 'network'] = 'SalVentAttn'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('Limbic'), 'network'] = 'Limbic'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('Cont'), 'network'] = 'Cont'
df_x_weights_sch_PSI.loc[df_x_weights_sch_PSI.network.str.contains('Default'), 'network'] = 'Default'

th = 3
df_x_weights_sch_PSI["weight_th"] =  (abs(df_x_weights_sch_PSI["weight"])>= th)*1


fig, axes = plt.subplots(1, 2, sharex=False, figsize=(15,5))
fig.suptitle('X weights cortical volumes EQF+TAB')

order_g = df_x_weights_sch_PSI.groupby(["network"]).mean().sort_values(by='weight').index
g = sns.barplot(x="network", y="weight", ax=axes[0], order= order_g,palette=yeo_pal,
            data=df_x_weights_sch_PSI)
g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
order_h = df_x_weights_sch_PSI.groupby(["network"]).sum().sort_values(by='weight_th').index
h = sns.barplot(x="network", y="weight_th", ci=None, ax=axes[1], estimator=sum,order= order_h,palette=yeo_pal,
            data=df_x_weights_sch_PSI)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)
# Incluir ROIs en una tabla

# %%
df_x_weights_sch_PSI = df_x_weights_sch_PSI[df_x_weights_sch_PSI['weight_th']>0]
df_x_weights_sch_PSI.reset_index(inplace=True)
df_x_weights_sch_PSI.columns = ['structure', 'weight','network','weight_th']
y = df_x_weights_sch_PSI[['structure','network']]
y = y.sort_values(by=['network'])

# %%
sch_x_v_weights_PSI = pls_PSI.bootres.x_weights_normed[:49,0]
df_x_weights_v_PSI = pd.DataFrame(sch_x_v_weights_PSI, columns=["weight"])
df_x_weights_v_PSI['volume'] = list(PSI_data.iloc[:,:49].columns)
#df_x_weights_v_TAB['category'] = ['Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','3rd-Ventricle','4th-Ventricle','Brain-Stem','Hippocampus','Amygdala','CSF','Accumbens-area','VentralDC','vessel','choroid-plexus','Lateral-Ventricle','Lateral-Ventricle','Cerebellum','Cerebellum','Thalamus','Caudate','Putamen','Pallidum','Hippocampus','Amygdala','Accumbens-area','VentralDC','vessel','choroid-plexus','Optic-Chiasm','CC','CC','CC','CC','CC']
th = 3
df_x_weights_v_PSI["weight_th"] =  (abs(df_x_weights_v_PSI["weight"])>= th)*1

fig, axes = plt.subplots(1, 2, sharex=True, figsize=(15,5))
fig.suptitle('X weights subcortical volumes EQF+TAB')

g=sns.barplot(x="volume", y="weight", ci=None, ax=axes[0],
            data=df_x_weights_v_PSI)
g.set(ylabel='weight intensity')
g.tick_params(labelrotation=60)
h = sns.barplot(x="volume", y="weight_th", ci=None, ax=axes[1], estimator=sum,
            data=df_x_weights_v_PSI)
h.set(ylabel='weight th count')
h.tick_params(labelrotation=60)

# %%
schaefer_image = 'Schaefer2018_400_17N_MNI152_2mm.nii' 
sch_masker=input_data.NiftiLabelsMasker(schaefer_image)
sch_values=sch_masker.fit()
th=3
values_brain_weight_vol = sch_masker.inverse_transform(sch_x_sch_weights_PSI[np.newaxis,:])
plotting.view_img(values_brain_weight_vol, threshold=th, title='X weights EQF+TAB', symmetric_cmap=False)

# %%
# Ploting stat map
#(barrido axial), que se puedan superponer los bordes de las redes (plot contours)
schaefer_image = 'Schaefer2018_400_17N_MNI152_2mm.nii'
display = plotting.plot_stat_map(values_brain_weight_vol, display_mode='mosaic', cut_coords=(3,3,3), title='X weights EQF+TAB', 
                       threshold=th, dim = 0, symmetric_cbar=False, black_bg=True,
                       colorbar=True)
display.add_contours(schaefer_image, cmap='Paired')

# %%
schaefer_image = 'Schaefer2018_400_17N_MNI152_2mm.nii'
sch_masker=input_data.NiftiLabelsMasker(schaefer_image)
sch_values=sch_masker.fit()
plotting.plot_roi(schaefer_image, view_type='contours', title="", cmap='Paired')
plotting.show()
